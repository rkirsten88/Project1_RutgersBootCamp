# %% [markdown]
# # STAR WARS: The Data Strikes Back

# %%
#import dependencies
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import scipy.stats as sts
from scipy.stats import linregress
import seaborn as sns

# %%
#API Calls - Endpoints with responses to reference 
##films
url_films = "http://swapi.dev/api/films/" 
films_response = requests.get(url_films).json()

##people
url_people = "http://swapi.dev/api/people/" 
people_response = requests.get(url_people).json()

##planets
url_planets = "http://swapi.dev/api/planets/"
planets_response = requests.get(url_planets).json()

##species
url_species = "http://swapi.dev/api/species/" 
species_response = requests.get(url_species).json()

##vehicles
url_vehicles = "http://swapi.dev/api/vehicles/" 
vehicles_response = requests.get(url_vehicles).json()

##starships
url_starships = "http://swapi.dev/api/starships/"
starships_response = requests.get(url_starships).json()

# %% [markdown]
# # Star Wars Film Call & Responses

# %%
#API Call for films
url_films = "http://swapi.dev/api/films/" 
films_response = requests.get(url_films).json()
## Film json dump (captioned out to save space)
print(json.dumps(films_response, indent=2, sort_keys=True))
# Out:
# {
#   "count": 6,
#   "next": null,
#   "previous": null,
#   "results": [
#     {
#       "characters": [
#         "http://swapi.dev/api/people/1/",
#         "http://swapi.dev/api/people/2/",
#         "http://swapi.dev/api/people/3/",
#         "http://swapi.dev/api/people/4/",
#         "http://swapi.dev/api/people/5/",
#         "http://swapi.dev/api/people/6/",
#         "http://swapi.dev/api/people/7/",
#         "http://swapi.dev/api/people/8/",
#         "http://swapi.dev/api/people/9/",
#         "http://swapi.dev/api/people/10/",
#         "http://swapi.dev/api/people/12/",
#         "http://swapi.dev/api/people/13/",
#         "http://swapi.dev/api/people/14/",
#         "http://swapi.dev/api/people/15/",
#         "http://swapi.dev/api/people/16/",
#         "http://swapi.dev/api/people/18/",
#         "http://swapi.dev/api/people/19/",
#         "http://swapi.dev/api/people/81/"
#       ],
#       "created": "2014-12-10T14:23:31.880000Z",
#       "director": "George Lucas",
#       "edited": "2014-12-20T19:49:45.256000Z",
#       "episode_id": 4,
#       "opening_crawl": "It is a period of civil war.\r\nRebel spaceships, striking\r\nfrom a hidden base, have won\r\ntheir first victory against\r\nthe evil Galactic Empire.\r\n\r\nDuring the battle, Rebel\r\nspies managed to steal secret\r\nplans to the Empire's\r\nultimate weapon, the DEATH\r\nSTAR, an armored space\r\nstation with enough power\r\nto destroy an entire planet.\r\n\r\nPursued by the Empire's\r\nsinister agents, Princess\r\nLeia races home aboard her\r\nstarship, custodian of the\r\nstolen plans that can save her\r\npeople and restore\r\nfreedom to the galaxy....",
#       "planets": [
#         "http://swapi.dev/api/planets/1/",
#         "http://swapi.dev/api/planets/2/",
#         "http://swapi.dev/api/planets/3/"
#       ],
#       "producer": "Gary Kurtz, Rick McCallum",
#       "release_date": "1977-05-25",
#       "species": [
#         "http://swapi.dev/api/species/1/",
#         "http://swapi.dev/api/species/2/",
#         "http://swapi.dev/api/species/3/",
#         "http://swapi.dev/api/species/4/",
#         "http://swapi.dev/api/species/5/"
#       ],
#       "starships": [
#         "http://swapi.dev/api/starships/2/",
#         "http://swapi.dev/api/starships/3/",
#         "http://swapi.dev/api/starships/5/",
#         "http://swapi.dev/api/starships/9/",
#         "http://swapi.dev/api/starships/10/",
#         "http://swapi.dev/api/starships/11/",
#         "http://swapi.dev/api/starships/12/",
#         "http://swapi.dev/api/starships/13/"
#       ],
#       "title": "A New Hope",
#       "url": "http://swapi.dev/api/films/1/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/4/",
#         "http://swapi.dev/api/vehicles/6/",
#         "http://swapi.dev/api/vehicles/7/",
#         "http://swapi.dev/api/vehicles/8/"
#       ]
#     },
#     {
#       "characters": [
#         "http://swapi.dev/api/people/1/",
#         "http://swapi.dev/api/people/2/",
#         "http://swapi.dev/api/people/3/",
#         "http://swapi.dev/api/people/4/",
#         "http://swapi.dev/api/people/5/",
#         "http://swapi.dev/api/people/10/",
#         "http://swapi.dev/api/people/13/",
#         "http://swapi.dev/api/people/14/",
#         "http://swapi.dev/api/people/18/",
#         "http://swapi.dev/api/people/20/",
#         "http://swapi.dev/api/people/21/",
#         "http://swapi.dev/api/people/22/",
#         "http://swapi.dev/api/people/23/",
#         "http://swapi.dev/api/people/24/",
#         "http://swapi.dev/api/people/25/",
#         "http://swapi.dev/api/people/26/"
#       ],
#       "created": "2014-12-12T11:26:24.656000Z",
#       "director": "Irvin Kershner",
#       "edited": "2014-12-15T13:07:53.386000Z",
#       "episode_id": 5,
#       "opening_crawl": "It is a dark time for the\r\nRebellion. Although the Death\r\nStar has been destroyed,\r\nImperial troops have driven the\r\nRebel forces from their hidden\r\nbase and pursued them across\r\nthe galaxy.\r\n\r\nEvading the dreaded Imperial\r\nStarfleet, a group of freedom\r\nfighters led by Luke Skywalker\r\nhas established a new secret\r\nbase on the remote ice world\r\nof Hoth.\r\n\r\nThe evil lord Darth Vader,\r\nobsessed with finding young\r\nSkywalker, has dispatched\r\nthousands of remote probes into\r\nthe far reaches of space....",
#       "planets": [
#         "http://swapi.dev/api/planets/4/",
#         "http://swapi.dev/api/planets/5/",
#         "http://swapi.dev/api/planets/6/",
#         "http://swapi.dev/api/planets/27/"
#       ],
#       "producer": "Gary Kurtz, Rick McCallum",
#       "release_date": "1980-05-17",
#       "species": [
#         "http://swapi.dev/api/species/1/",
#         "http://swapi.dev/api/species/2/",
#         "http://swapi.dev/api/species/3/",
#         "http://swapi.dev/api/species/6/",
#         "http://swapi.dev/api/species/7/"
#       ],
#       "starships": [
#         "http://swapi.dev/api/starships/3/",
#         "http://swapi.dev/api/starships/10/",
#         "http://swapi.dev/api/starships/11/",
#         "http://swapi.dev/api/starships/12/",
#         "http://swapi.dev/api/starships/15/",
#         "http://swapi.dev/api/starships/17/",
#         "http://swapi.dev/api/starships/21/",
#         "http://swapi.dev/api/starships/22/",
#         "http://swapi.dev/api/starships/23/"
#       ],
#       "title": "The Empire Strikes Back",
#       "url": "http://swapi.dev/api/films/2/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/8/",
#         "http://swapi.dev/api/vehicles/14/",
#         "http://swapi.dev/api/vehicles/16/",
#         "http://swapi.dev/api/vehicles/18/",
#         "http://swapi.dev/api/vehicles/19/",
#         "http://swapi.dev/api/vehicles/20/"
#       ]
#     },
#     {
#       "characters": [
#         "http://swapi.dev/api/people/1/",
#         "http://swapi.dev/api/people/2/",
#         "http://swapi.dev/api/people/3/",
#         "http://swapi.dev/api/people/4/",
#         "http://swapi.dev/api/people/5/",
#         "http://swapi.dev/api/people/10/",
#         "http://swapi.dev/api/people/13/",
#         "http://swapi.dev/api/people/14/",
#         "http://swapi.dev/api/people/16/",
#         "http://swapi.dev/api/people/18/",
#         "http://swapi.dev/api/people/20/",
#         "http://swapi.dev/api/people/21/",
#         "http://swapi.dev/api/people/22/",
#         "http://swapi.dev/api/people/25/",
#         "http://swapi.dev/api/people/27/",
#         "http://swapi.dev/api/people/28/",
#         "http://swapi.dev/api/people/29/",
#         "http://swapi.dev/api/people/30/",
#         "http://swapi.dev/api/people/31/",
#         "http://swapi.dev/api/people/45/"
#       ],
#       "created": "2014-12-18T10:39:33.255000Z",
#       "director": "Richard Marquand",
#       "edited": "2014-12-20T09:48:37.462000Z",
#       "episode_id": 6,
#       "opening_crawl": "Luke Skywalker has returned to\r\nhis home planet of Tatooine in\r\nan attempt to rescue his\r\nfriend Han Solo from the\r\nclutches of the vile gangster\r\nJabba the Hutt.\r\n\r\nLittle does Luke know that the\r\nGALACTIC EMPIRE has secretly\r\nbegun construction on a new\r\narmored space station even\r\nmore powerful than the first\r\ndreaded Death Star.\r\n\r\nWhen completed, this ultimate\r\nweapon will spell certain doom\r\nfor the small band of rebels\r\nstruggling to restore freedom\r\nto the galaxy...",
#       "planets": [
#         "http://swapi.dev/api/planets/1/",
#         "http://swapi.dev/api/planets/5/",
#         "http://swapi.dev/api/planets/7/",
#         "http://swapi.dev/api/planets/8/",
#         "http://swapi.dev/api/planets/9/"
#       ],
#       "producer": "Howard G. Kazanjian, George Lucas, Rick McCallum",
#       "release_date": "1983-05-25",
#       "species": [
#         "http://swapi.dev/api/species/1/",
#         "http://swapi.dev/api/species/2/",
#         "http://swapi.dev/api/species/3/",
#         "http://swapi.dev/api/species/5/",
#         "http://swapi.dev/api/species/6/",
#         "http://swapi.dev/api/species/8/",
#         "http://swapi.dev/api/species/9/",
#         "http://swapi.dev/api/species/10/",
#         "http://swapi.dev/api/species/15/"
#       ],
#       "starships": [
#         "http://swapi.dev/api/starships/2/",
#         "http://swapi.dev/api/starships/3/",
#         "http://swapi.dev/api/starships/10/",
#         "http://swapi.dev/api/starships/11/",
#         "http://swapi.dev/api/starships/12/",
#         "http://swapi.dev/api/starships/15/",
#         "http://swapi.dev/api/starships/17/",
#         "http://swapi.dev/api/starships/22/",
#         "http://swapi.dev/api/starships/23/",
#         "http://swapi.dev/api/starships/27/",
#         "http://swapi.dev/api/starships/28/",
#         "http://swapi.dev/api/starships/29/"
#       ],
#       "title": "Return of the Jedi",
#       "url": "http://swapi.dev/api/films/3/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/8/",
#         "http://swapi.dev/api/vehicles/16/",
#         "http://swapi.dev/api/vehicles/18/",
#         "http://swapi.dev/api/vehicles/19/",
#         "http://swapi.dev/api/vehicles/24/",
#         "http://swapi.dev/api/vehicles/25/",
#         "http://swapi.dev/api/vehicles/26/",
#         "http://swapi.dev/api/vehicles/30/"
#       ]
#     },
#     {
#       "characters": [
#         "http://swapi.dev/api/people/2/",
#         "http://swapi.dev/api/people/3/",
#         "http://swapi.dev/api/people/10/",
#         "http://swapi.dev/api/people/11/",
#         "http://swapi.dev/api/people/16/",
#         "http://swapi.dev/api/people/20/",
#         "http://swapi.dev/api/people/21/",
#         "http://swapi.dev/api/people/32/",
#         "http://swapi.dev/api/people/33/",
#         "http://swapi.dev/api/people/34/",
#         "http://swapi.dev/api/people/35/",
#         "http://swapi.dev/api/people/36/",
#         "http://swapi.dev/api/people/37/",
#         "http://swapi.dev/api/people/38/",
#         "http://swapi.dev/api/people/39/",
#         "http://swapi.dev/api/people/40/",
#         "http://swapi.dev/api/people/41/",
#         "http://swapi.dev/api/people/42/",
#         "http://swapi.dev/api/people/43/",
#         "http://swapi.dev/api/people/44/",
#         "http://swapi.dev/api/people/46/",
#         "http://swapi.dev/api/people/47/",
#         "http://swapi.dev/api/people/48/",
#         "http://swapi.dev/api/people/49/",
#         "http://swapi.dev/api/people/50/",
#         "http://swapi.dev/api/people/51/",
#         "http://swapi.dev/api/people/52/",
#         "http://swapi.dev/api/people/53/",
#         "http://swapi.dev/api/people/54/",
#         "http://swapi.dev/api/people/55/",
#         "http://swapi.dev/api/people/56/",
#         "http://swapi.dev/api/people/57/",
#         "http://swapi.dev/api/people/58/",
#         "http://swapi.dev/api/people/59/"
#       ],
#       "created": "2014-12-19T16:52:55.740000Z",
#       "director": "George Lucas",
#       "edited": "2014-12-20T10:54:07.216000Z",
#       "episode_id": 1,
#       "opening_crawl": "Turmoil has engulfed the\r\nGalactic Republic. The taxation\r\nof trade routes to outlying star\r\nsystems is in dispute.\r\n\r\nHoping to resolve the matter\r\nwith a blockade of deadly\r\nbattleships, the greedy Trade\r\nFederation has stopped all\r\nshipping to the small planet\r\nof Naboo.\r\n\r\nWhile the Congress of the\r\nRepublic endlessly debates\r\nthis alarming chain of events,\r\nthe Supreme Chancellor has\r\nsecretly dispatched two Jedi\r\nKnights, the guardians of\r\npeace and justice in the\r\ngalaxy, to settle the conflict....",
#       "planets": [
#         "http://swapi.dev/api/planets/1/",
#         "http://swapi.dev/api/planets/8/",
#         "http://swapi.dev/api/planets/9/"
#       ],
#       "producer": "Rick McCallum",
#       "release_date": "1999-05-19",
#       "species": [
#         "http://swapi.dev/api/species/1/",
#         "http://swapi.dev/api/species/2/",
#         "http://swapi.dev/api/species/6/",
#         "http://swapi.dev/api/species/11/",
#         "http://swapi.dev/api/species/12/",
#         "http://swapi.dev/api/species/13/",
#         "http://swapi.dev/api/species/14/",
#         "http://swapi.dev/api/species/15/",
#         "http://swapi.dev/api/species/16/",
#         "http://swapi.dev/api/species/17/",
#         "http://swapi.dev/api/species/18/",
#         "http://swapi.dev/api/species/19/",
#         "http://swapi.dev/api/species/20/",
#         "http://swapi.dev/api/species/21/",
#         "http://swapi.dev/api/species/22/",
#         "http://swapi.dev/api/species/23/",
#         "http://swapi.dev/api/species/24/",
#         "http://swapi.dev/api/species/25/",
#         "http://swapi.dev/api/species/26/",
#         "http://swapi.dev/api/species/27/"
#       ],
#       "starships": [
#         "http://swapi.dev/api/starships/31/",
#         "http://swapi.dev/api/starships/32/",
#         "http://swapi.dev/api/starships/39/",
#         "http://swapi.dev/api/starships/40/",
#         "http://swapi.dev/api/starships/41/"
#       ],
#       "title": "The Phantom Menace",
#       "url": "http://swapi.dev/api/films/4/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/33/",
#         "http://swapi.dev/api/vehicles/34/",
#         "http://swapi.dev/api/vehicles/35/",
#         "http://swapi.dev/api/vehicles/36/",
#         "http://swapi.dev/api/vehicles/37/",
#         "http://swapi.dev/api/vehicles/38/",
#         "http://swapi.dev/api/vehicles/42/"
#       ]
#     },
#     {
#       "characters": [
#         "http://swapi.dev/api/people/2/",
#         "http://swapi.dev/api/people/3/",
#         "http://swapi.dev/api/people/6/",
#         "http://swapi.dev/api/people/7/",
#         "http://swapi.dev/api/people/10/",
#         "http://swapi.dev/api/people/11/",
#         "http://swapi.dev/api/people/20/",
#         "http://swapi.dev/api/people/21/",
#         "http://swapi.dev/api/people/22/",
#         "http://swapi.dev/api/people/33/",
#         "http://swapi.dev/api/people/35/",
#         "http://swapi.dev/api/people/36/",
#         "http://swapi.dev/api/people/40/",
#         "http://swapi.dev/api/people/43/",
#         "http://swapi.dev/api/people/46/",
#         "http://swapi.dev/api/people/51/",
#         "http://swapi.dev/api/people/52/",
#         "http://swapi.dev/api/people/53/",
#         "http://swapi.dev/api/people/58/",
#         "http://swapi.dev/api/people/59/",
#         "http://swapi.dev/api/people/60/",
#         "http://swapi.dev/api/people/61/",
#         "http://swapi.dev/api/people/62/",
#         "http://swapi.dev/api/people/63/",
#         "http://swapi.dev/api/people/64/",
#         "http://swapi.dev/api/people/65/",
#         "http://swapi.dev/api/people/66/",
#         "http://swapi.dev/api/people/67/",
#         "http://swapi.dev/api/people/68/",
#         "http://swapi.dev/api/people/69/",
#         "http://swapi.dev/api/people/70/",
#         "http://swapi.dev/api/people/71/",
#         "http://swapi.dev/api/people/72/",
#         "http://swapi.dev/api/people/73/",
#         "http://swapi.dev/api/people/74/",
#         "http://swapi.dev/api/people/75/",
#         "http://swapi.dev/api/people/76/",
#         "http://swapi.dev/api/people/77/",
#         "http://swapi.dev/api/people/78/",
#         "http://swapi.dev/api/people/82/"
#       ],
#       "created": "2014-12-20T10:57:57.886000Z",
#       "director": "George Lucas",
#       "edited": "2014-12-20T20:18:48.516000Z",
#       "episode_id": 2,
#       "opening_crawl": "There is unrest in the Galactic\r\nSenate. Several thousand solar\r\nsystems have declared their\r\nintentions to leave the Republic.\r\n\r\nThis separatist movement,\r\nunder the leadership of the\r\nmysterious Count Dooku, has\r\nmade it difficult for the limited\r\nnumber of Jedi Knights to maintain \r\npeace and order in the galaxy.\r\n\r\nSenator Amidala, the former\r\nQueen of Naboo, is returning\r\nto the Galactic Senate to vote\r\non the critical issue of creating\r\nan ARMY OF THE REPUBLIC\r\nto assist the overwhelmed\r\nJedi....",
#       "planets": [
#         "http://swapi.dev/api/planets/1/",
#         "http://swapi.dev/api/planets/8/",
#         "http://swapi.dev/api/planets/9/",
#         "http://swapi.dev/api/planets/10/",
#         "http://swapi.dev/api/planets/11/"
#       ],
#       "producer": "Rick McCallum",
#       "release_date": "2002-05-16",
#       "species": [
#         "http://swapi.dev/api/species/1/",
#         "http://swapi.dev/api/species/2/",
#         "http://swapi.dev/api/species/6/",
#         "http://swapi.dev/api/species/12/",
#         "http://swapi.dev/api/species/13/",
#         "http://swapi.dev/api/species/15/",
#         "http://swapi.dev/api/species/28/",
#         "http://swapi.dev/api/species/29/",
#         "http://swapi.dev/api/species/30/",
#         "http://swapi.dev/api/species/31/",
#         "http://swapi.dev/api/species/32/",
#         "http://swapi.dev/api/species/33/",
#         "http://swapi.dev/api/species/34/",
#         "http://swapi.dev/api/species/35/"
#       ],
#       "starships": [
#         "http://swapi.dev/api/starships/21/",
#         "http://swapi.dev/api/starships/32/",
#         "http://swapi.dev/api/starships/39/",
#         "http://swapi.dev/api/starships/43/",
#         "http://swapi.dev/api/starships/47/",
#         "http://swapi.dev/api/starships/48/",
#         "http://swapi.dev/api/starships/49/",
#         "http://swapi.dev/api/starships/52/",
#         "http://swapi.dev/api/starships/58/"
#       ],
#       "title": "Attack of the Clones",
#       "url": "http://swapi.dev/api/films/5/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/4/",
#         "http://swapi.dev/api/vehicles/44/",
#         "http://swapi.dev/api/vehicles/45/",
#         "http://swapi.dev/api/vehicles/46/",
#         "http://swapi.dev/api/vehicles/50/",
#         "http://swapi.dev/api/vehicles/51/",
#         "http://swapi.dev/api/vehicles/53/",
#         "http://swapi.dev/api/vehicles/54/",
#         "http://swapi.dev/api/vehicles/55/",
#         "http://swapi.dev/api/vehicles/56/",
#         "http://swapi.dev/api/vehicles/57/"
#       ]
#     },
#     {
#       "characters": [
#         "http://swapi.dev/api/people/1/",
#         "http://swapi.dev/api/people/2/",
#         "http://swapi.dev/api/people/3/",
#         "http://swapi.dev/api/people/4/",
#         "http://swapi.dev/api/people/5/",
#         "http://swapi.dev/api/people/6/",
#         "http://swapi.dev/api/people/7/",
#         "http://swapi.dev/api/people/10/",
#         "http://swapi.dev/api/people/11/",
#         "http://swapi.dev/api/people/12/",
#         "http://swapi.dev/api/people/13/",
#         "http://swapi.dev/api/people/20/",
#         "http://swapi.dev/api/people/21/",
#         "http://swapi.dev/api/people/33/",
#         "http://swapi.dev/api/people/35/",
#         "http://swapi.dev/api/people/46/",
#         "http://swapi.dev/api/people/51/",
#         "http://swapi.dev/api/people/52/",
#         "http://swapi.dev/api/people/53/",
#         "http://swapi.dev/api/people/54/",
#         "http://swapi.dev/api/people/55/",
#         "http://swapi.dev/api/people/56/",
#         "http://swapi.dev/api/people/58/",
#         "http://swapi.dev/api/people/63/",
#         "http://swapi.dev/api/people/64/",
#         "http://swapi.dev/api/people/67/",
#         "http://swapi.dev/api/people/68/",
#         "http://swapi.dev/api/people/75/",
#         "http://swapi.dev/api/people/78/",
#         "http://swapi.dev/api/people/79/",
#         "http://swapi.dev/api/people/80/",
#         "http://swapi.dev/api/people/81/",
#         "http://swapi.dev/api/people/82/",
#         "http://swapi.dev/api/people/83/"
#       ],
#       "created": "2014-12-20T18:49:38.403000Z",
#       "director": "George Lucas",
#       "edited": "2014-12-20T20:47:52.073000Z",
#       "episode_id": 3,
#       "opening_crawl": "War! The Republic is crumbling\r\nunder attacks by the ruthless\r\nSith Lord, Count Dooku.\r\nThere are heroes on both sides.\r\nEvil is everywhere.\r\n\r\nIn a stunning move, the\r\nfiendish droid leader, General\r\nGrievous, has swept into the\r\nRepublic capital and kidnapped\r\nChancellor Palpatine, leader of\r\nthe Galactic Senate.\r\n\r\nAs the Separatist Droid Army\r\nattempts to flee the besieged\r\ncapital with their valuable\r\nhostage, two Jedi Knights lead a\r\ndesperate mission to rescue the\r\ncaptive Chancellor....",
#       "planets": [
#         "http://swapi.dev/api/planets/1/",
#         "http://swapi.dev/api/planets/2/",
#         "http://swapi.dev/api/planets/5/",
#         "http://swapi.dev/api/planets/8/",
#         "http://swapi.dev/api/planets/9/",
#         "http://swapi.dev/api/planets/12/",
#         "http://swapi.dev/api/planets/13/",
#         "http://swapi.dev/api/planets/14/",
#         "http://swapi.dev/api/planets/15/",
#         "http://swapi.dev/api/planets/16/",
#         "http://swapi.dev/api/planets/17/",
#         "http://swapi.dev/api/planets/18/",
#         "http://swapi.dev/api/planets/19/"
#       ],
#       "producer": "Rick McCallum",
#       "release_date": "2005-05-19",
#       "species": [
#         "http://swapi.dev/api/species/1/",
#         "http://swapi.dev/api/species/2/",
#         "http://swapi.dev/api/species/3/",
#         "http://swapi.dev/api/species/6/",
#         "http://swapi.dev/api/species/15/",
#         "http://swapi.dev/api/species/19/",
#         "http://swapi.dev/api/species/20/",
#         "http://swapi.dev/api/species/23/",
#         "http://swapi.dev/api/species/24/",
#         "http://swapi.dev/api/species/25/",
#         "http://swapi.dev/api/species/26/",
#         "http://swapi.dev/api/species/27/",
#         "http://swapi.dev/api/species/28/",
#         "http://swapi.dev/api/species/29/",
#         "http://swapi.dev/api/species/30/",
#         "http://swapi.dev/api/species/33/",
#         "http://swapi.dev/api/species/34/",
#         "http://swapi.dev/api/species/35/",
#         "http://swapi.dev/api/species/36/",
#         "http://swapi.dev/api/species/37/"
#       ],
#       "starships": [
#         "http://swapi.dev/api/starships/2/",
#         "http://swapi.dev/api/starships/32/",
#         "http://swapi.dev/api/starships/48/",
#         "http://swapi.dev/api/starships/59/",
#         "http://swapi.dev/api/starships/61/",
#         "http://swapi.dev/api/starships/63/",
#         "http://swapi.dev/api/starships/64/",
#         "http://swapi.dev/api/starships/65/",
#         "http://swapi.dev/api/starships/66/",
#         "http://swapi.dev/api/starships/68/",
#         "http://swapi.dev/api/starships/74/",
#         "http://swapi.dev/api/starships/75/"
#       ],
#       "title": "Revenge of the Sith",
#       "url": "http://swapi.dev/api/films/6/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/33/",
#         "http://swapi.dev/api/vehicles/50/",
#         "http://swapi.dev/api/vehicles/53/",
#         "http://swapi.dev/api/vehicles/56/",
#         "http://swapi.dev/api/vehicles/60/",
#         "http://swapi.dev/api/vehicles/62/",
#         "http://swapi.dev/api/vehicles/67/",
#         "http://swapi.dev/api/vehicles/69/",
#         "http://swapi.dev/api/vehicles/70/",
#         "http://swapi.dev/api/vehicles/71/",
#         "http://swapi.dev/api/vehicles/72/",
#         "http://swapi.dev/api/vehicles/73/",
#         "http://swapi.dev/api/vehicles/76/"
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## Pull all FILMS and specified data

# %%
#set up lists to store film data
film_counter=0
film_title = []
film_episode_id = []
film_release_date = []
film_url = []
species_per_film = []
characters_per_film = []
planets_per_film = []
vehicles_per_film = []
starships_per_film = []

#loop through film data and append lists
for films in films_response["results"]:
    movie_title = films["title"]
    film_title.append(movie_title)
    episode_number = films["episode_id"]
    film_episode_id.append(episode_number)
    date_released = films["release_date"]
    film_release_date.append(date_released)
    movie_url = films["url"]
    film_url.append(movie_url)
    species_film = films["species"]
    species_per_film.append(species_film)
    film_characters = films["characters"]
    characters_per_film.append(film_characters)
    film_planets = films["planets"]
    planets_per_film.append(film_planets)
    film_vehicles = films["vehicles"]
    vehicles_per_film.append(film_vehicles)
    film_starships = films["starships"]
    starships_per_film.append(film_starships)    
    film_counter+=1
    print(f'Film {film_counter} Found! Star Wars Episode {episode_number}: {movie_title} | Release Date: {date_released}')
# Out:
# Film 1 Found! Star Wars Episode 4: A New Hope | Release Date: 1977-05-25
# Film 2 Found! Star Wars Episode 5: The Empire Strikes Back | Release Date: 1980-05-17
# Film 3 Found! Star Wars Episode 6: Return of the Jedi | Release Date: 1983-05-25
# Film 4 Found! Star Wars Episode 1: The Phantom Menace | Release Date: 1999-05-19
# Film 5 Found! Star Wars Episode 2: Attack of the Clones | Release Date: 2002-05-16
# Film 6 Found! Star Wars Episode 3: Revenge of the Sith | Release Date: 2005-05-19

# %%
#Pull number of X per film
species_per_film_series = pd.Series([len(species_per_film[0]),
                                    len(species_per_film[1]),
                                    len(species_per_film[2]), 
                                    len(species_per_film[3]), 
                                    len(species_per_film[4]), 
                                    len(species_per_film[5])])

print(f'Species Per Film: {species_per_film_series}')

characters_per_film_series = pd.Series([len(characters_per_film[0]),
                                    len(characters_per_film[1]),
                                    len(characters_per_film[2]), 
                                    len(characters_per_film[3]), 
                                    len(characters_per_film[4]), 
                                    len(characters_per_film[5])])

print(f'Characters Per Film: {characters_per_film_series}')

planets_per_film_series = pd.Series([len(planets_per_film[0]),
                                    len(planets_per_film[1]),
                                    len(planets_per_film[2]), 
                                    len(planets_per_film[3]), 
                                    len(planets_per_film[4]), 
                                    len(planets_per_film[5])])

print(planets_per_film_series)

print(f'Planets Per Film: {planets_per_film_series}')
vehicles_per_film_series = pd.Series([len(vehicles_per_film[0]),
                                    len(vehicles_per_film[1]),
                                    len(vehicles_per_film[2]), 
                                    len(vehicles_per_film[3]), 
                                    len(vehicles_per_film[4]), 
                                    len(vehicles_per_film[5])])

print(f'Vehicles Per Film: {vehicles_per_film_series}')

starships_per_film_series = pd.Series([len(starships_per_film[0]),
                                    len(starships_per_film[1]),
                                    len(starships_per_film[2]), 
                                    len(starships_per_film[3]), 
                                    len(starships_per_film[4]), 
                                    len(starships_per_film[5])])

print(f'Starships Per Film: {starships_per_film_series}')
# Out:
# Species Per Film: 0     5
# 1     5
# 2     9
# 3    20
# 4    14
# 5    20
# dtype: int64
# Characters Per Film: 0    18
# 1    16
# 2    20
# 3    34
# 4    40
# 5    34
# dtype: int64
# 0     3
# 1     4
# 2     5
# 3     3
# 4     5
# 5    13
# dtype: int64
# Planets Per Film: 0     3
# 1     4
# 2     5
# 3     3
# 4     5
# 5    13
# dtype: int64
# Vehicles Per Film: 0     4
# 1     6
# 2     8
# 3     7
# 4    11
# 5    13
# dtype: int64
# Starships Per Film: 0     8
# 1     9
# 2    12
# 3     5
# 4     9
# 5    12
# dtype: int64

# %%
#create new dataframe for film data
films_df = pd.DataFrame({"Title": film_title,
                        "Episode ID": film_episode_id,
                        "Release Date": film_release_date,
                        "URL": film_url,
                        "Number of Characters": characters_per_film_series,                        
                        "Number of Species": species_per_film_series,
                        "Number of Planets": planets_per_film_series,
                        "Number of Vehicles": vehicles_per_film_series,
                        "Number of Starships": starships_per_film_series})
films_df.to_csv("csv_output/films_to_clean.csv")
films_df
# Out:
#                      Title  Episode ID Release Date  \
# 0               A New Hope           4   1977-05-25
# 1  The Empire Strikes Back           5   1980-05-17
# 2       Return of the Jedi           6   1983-05-25
# 3       The Phantom Menace           1   1999-05-19
# 4     Attack of the Clones           2   2002-05-16
# 5      Revenge of the Sith           3   2005-05-19
#
#                              URL  Number of Characters  Number of Species  \
# 0  http://swapi.dev/api/films/1/                    18                  5
# 1  http://swapi.dev/api/films/2/                    16                  5
# 2  http://swapi.dev/api/films/3/                    20                  9
# 3  http://swapi.dev/api/films/4/                    34                 20
# 4  http://swapi.dev/api/films/5/                    40                 14
# 5  http://swapi.dev/api/films/6/                    34                 20
#
#    Number of Planets  Number of Vehicles  Number of Starships
# 0                  3                   4                    8
# 1                  4                   6                    9
# 2                  5                   8                   12
# 3                  3                   7                    5
# 4                  5                  11                    9
# 5                 13                  13                   12

# %%
#create new dataframe for film data
bar_plot_df = pd.DataFrame({"Title": film_title,
                            "Number of Characters": characters_per_film_series,
                            "Number of Species": species_per_film_series,
                            "Number of Planets": planets_per_film_series,
                            "Number of Vehicles": vehicles_per_film_series,
                            "Number of Starships": starships_per_film_series})

bar_plot_df
# Out:
#                      Title  Number of Characters  Number of Species  \
# 0               A New Hope                    18                  5
# 1  The Empire Strikes Back                    16                  5
# 2       Return of the Jedi                    20                  9
# 3       The Phantom Menace                    34                 20
# 4     Attack of the Clones                    40                 14
# 5      Revenge of the Sith                    34                 20
#
#    Number of Planets  Number of Vehicles  Number of Starships
# 0                  3                   4                    8
# 1                  4                   6                    9
# 2                  5                   8                   12
# 3                  3                   7                    5
# 4                  5                  11                    9
# 5                 13                  13                   12

# %%
#bar plot number of X per film
labels = films_df["Title"]
tick_locations = np.arange(len(bar_plot_df))
data_per_film_bar_plot = bar_plot_df.plot.bar(rot=0)
plt.xticks(tick_locations, labels, rotation="vertical")
plt.title("Star Wars: Number of 'X' Per Film [Release Order]")
plt.xlabel("Films")
plt.ylabel("Number Per Film")
plt.grid()
plt.savefig("Figures/Bar_All_Per_Film_ReleaseOrder.png")



plt.show()

# %%
#line plot showing how number of things changed over time
tick_locations = np.arange(len(bar_plot_df))
labels = films_df["Title"]
data_per_film_line_plot = bar_plot_df.plot.line(rot=0)
plt.xticks(tick_locations, labels, rotation="vertical")
plt.title("Star Wars: How Counts Change Over Time [Release Order]")
plt.xlabel("Films")
plt.ylabel("Number Per Film")
plt.grid()
plt.savefig("Figures/Line_All_Per_Film_ReleaseOrder.png")
plt.show()

# %%
#Create a new Dataframe to drop the URL column but keep the episode ID column to sort by
films_presentation_df = films_df.drop(columns=(["URL"]))
films_presentation_df
# Out:
#                      Title  Episode ID Release Date  Number of Characters  \
# 0               A New Hope           4   1977-05-25                    18
# 1  The Empire Strikes Back           5   1980-05-17                    16
# 2       Return of the Jedi           6   1983-05-25                    20
# 3       The Phantom Menace           1   1999-05-19                    34
# 4     Attack of the Clones           2   2002-05-16                    40
# 5      Revenge of the Sith           3   2005-05-19                    34
#
#    Number of Species  Number of Planets  Number of Vehicles  \
# 0                  5                  3                   4
# 1                  5                  4                   6
# 2                  9                  5                   8
# 3                 20                  3                   7
# 4                 14                  5                  11
# 5                 20                 13                  13
#
#    Number of Starships
# 0                    8
# 1                    9
# 2                   12
# 3                    5
# 4                    9
# 5                   12

# %%
#create new dataframe for film data
line_plot_df = pd.DataFrame({"Title": film_title,
                            "Number of Characters": characters_per_film_series,
                            "Number of Species": species_per_film_series,
                            "Number of Planets": planets_per_film_series,
                            "Number of Vehicles": vehicles_per_film_series,
                            "Number of Starships": starships_per_film_series})

bar_plot_df
# Out:
#                      Title  Number of Characters  Number of Species  \
# 0               A New Hope                    18                  5
# 1  The Empire Strikes Back                    16                  5
# 2       Return of the Jedi                    20                  9
# 3       The Phantom Menace                    34                 20
# 4     Attack of the Clones                    40                 14
# 5      Revenge of the Sith                    34                 20
#
#    Number of Planets  Number of Vehicles  Number of Starships
# 0                  3                   4                    8
# 1                  4                   6                    9
# 2                  5                   8                   12
# 3                  3                   7                    5
# 4                  5                  11                    9
# 5                 13                  13                   12

# %%
#Now that it's sorted, remove episode ID and Release Date in order to create a new Dataframe for plotting
films_chrono_df = films_presentation_df.sort_values("Episode ID", ascending = True)
barplot_films_chrono_df = films_chrono_df.drop(columns=(["Release Date", "Episode ID"]))
barplot_films_chrono_df = barplot_films_chrono_df.reset_index(drop=True)
barplot_films_chrono_df
# Out:
#                      Title  Number of Characters  Number of Species  \
# 0       The Phantom Menace                    34                 20
# 1     Attack of the Clones                    40                 14
# 2      Revenge of the Sith                    34                 20
# 3               A New Hope                    18                  5
# 4  The Empire Strikes Back                    16                  5
# 5       Return of the Jedi                    20                  9
#
#    Number of Planets  Number of Vehicles  Number of Starships
# 0                  3                   7                    5
# 1                  5                  11                    9
# 2                 13                  13                   12
# 3                  3                   4                    8
# 4                  4                   6                    9
# 5                  5                   8                   12

# %%
#line plot showing how number of things changed over time
tick_locations = np.arange(len(barplot_films_chrono_df))
labels = barplot_films_chrono_df["Title"]
data_per_film_line_plot_2 = barplot_films_chrono_df.plot.line(rot=0)
plt.xticks(tick_locations, labels, rotation="vertical")
plt.title("Star Wars: How Counts Change Over Time [In Universe]")
plt.xlabel("Films")
plt.ylabel("Number Per Film")
plt.grid()
plt.savefig("Figures/Line_All_Per_Film_InUniverse.png")
plt.show()

# %%
#bar plot number of X per film
labels = barplot_films_chrono_df["Title"]
tick_locations = np.arange(len(barplot_films_chrono_df))
data_per_film_bar_plot = barplot_films_chrono_df.plot.bar(rot=0)
plt.xticks(tick_locations, labels, rotation="vertical")
plt.title("Star Wars: Number of 'X' Per Film [In Universe]")
plt.xlabel("Films")
plt.ylabel("Number Per Film")
plt.grid()
plt.savefig("Figures/Bar_All_Per_Film_InUniverse.png")



plt.show()

# %% [markdown]
# # Star Wars Characters

# %%
# People/Characters json dump
print(json.dumps(people_response, indent=2, sort_keys=True))
# Out:
# {
#   "count": 82,
#   "next": "http://swapi.dev/api/people/?page=2",
#   "previous": null,
#   "results": [
#     {
#       "birth_year": "19BBY",
#       "created": "2014-12-09T13:50:51.644000Z",
#       "edited": "2014-12-20T21:17:56.891000Z",
#       "eye_color": "blue",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "male",
#       "hair_color": "blond",
#       "height": "172",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "77",
#       "name": "Luke Skywalker",
#       "skin_color": "fair",
#       "species": [],
#       "starships": [
#         "http://swapi.dev/api/starships/12/",
#         "http://swapi.dev/api/starships/22/"
#       ],
#       "url": "http://swapi.dev/api/people/1/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/14/",
#         "http://swapi.dev/api/vehicles/30/"
#       ]
#     },
#     {
#       "birth_year": "112BBY",
#       "created": "2014-12-10T15:10:51.357000Z",
#       "edited": "2014-12-20T21:17:50.309000Z",
#       "eye_color": "yellow",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "n/a",
#       "hair_color": "n/a",
#       "height": "167",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "75",
#       "name": "C-3PO",
#       "skin_color": "gold",
#       "species": [
#         "http://swapi.dev/api/species/2/"
#       ],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/2/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "33BBY",
#       "created": "2014-12-10T15:11:50.376000Z",
#       "edited": "2014-12-20T21:17:50.311000Z",
#       "eye_color": "red",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "n/a",
#       "hair_color": "n/a",
#       "height": "96",
#       "homeworld": "http://swapi.dev/api/planets/8/",
#       "mass": "32",
#       "name": "R2-D2",
#       "skin_color": "white, blue",
#       "species": [
#         "http://swapi.dev/api/species/2/"
#       ],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/3/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "41.9BBY",
#       "created": "2014-12-10T15:18:20.704000Z",
#       "edited": "2014-12-20T21:17:50.313000Z",
#       "eye_color": "yellow",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "male",
#       "hair_color": "none",
#       "height": "202",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "136",
#       "name": "Darth Vader",
#       "skin_color": "white",
#       "species": [],
#       "starships": [
#         "http://swapi.dev/api/starships/13/"
#       ],
#       "url": "http://swapi.dev/api/people/4/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "19BBY",
#       "created": "2014-12-10T15:20:09.791000Z",
#       "edited": "2014-12-20T21:17:50.315000Z",
#       "eye_color": "brown",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "female",
#       "hair_color": "brown",
#       "height": "150",
#       "homeworld": "http://swapi.dev/api/planets/2/",
#       "mass": "49",
#       "name": "Leia Organa",
#       "skin_color": "light",
#       "species": [],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/5/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/30/"
#       ]
#     },
#     {
#       "birth_year": "52BBY",
#       "created": "2014-12-10T15:52:14.024000Z",
#       "edited": "2014-12-20T21:17:50.317000Z",
#       "eye_color": "blue",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "male",
#       "hair_color": "brown, grey",
#       "height": "178",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "120",
#       "name": "Owen Lars",
#       "skin_color": "light",
#       "species": [],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/6/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "47BBY",
#       "created": "2014-12-10T15:53:41.121000Z",
#       "edited": "2014-12-20T21:17:50.319000Z",
#       "eye_color": "blue",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "female",
#       "hair_color": "brown",
#       "height": "165",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "75",
#       "name": "Beru Whitesun lars",
#       "skin_color": "light",
#       "species": [],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/7/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "unknown",
#       "created": "2014-12-10T15:57:50.959000Z",
#       "edited": "2014-12-20T21:17:50.321000Z",
#       "eye_color": "red",
#       "films": [
#         "http://swapi.dev/api/films/1/"
#       ],
#       "gender": "n/a",
#       "hair_color": "n/a",
#       "height": "97",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "32",
#       "name": "R5-D4",
#       "skin_color": "white, red",
#       "species": [
#         "http://swapi.dev/api/species/2/"
#       ],
#       "starships": [],
#       "url": "http://swapi.dev/api/people/8/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "24BBY",
#       "created": "2014-12-10T15:59:50.509000Z",
#       "edited": "2014-12-20T21:17:50.323000Z",
#       "eye_color": "brown",
#       "films": [
#         "http://swapi.dev/api/films/1/"
#       ],
#       "gender": "male",
#       "hair_color": "black",
#       "height": "183",
#       "homeworld": "http://swapi.dev/api/planets/1/",
#       "mass": "84",
#       "name": "Biggs Darklighter",
#       "skin_color": "light",
#       "species": [],
#       "starships": [
#         "http://swapi.dev/api/starships/12/"
#       ],
#       "url": "http://swapi.dev/api/people/9/",
#       "vehicles": []
#     },
#     {
#       "birth_year": "57BBY",
#       "created": "2014-12-10T16:16:29.192000Z",
#       "edited": "2014-12-20T21:17:50.325000Z",
#       "eye_color": "blue-gray",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/4/",
#         "http://swapi.dev/api/films/5/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "gender": "male",
#       "hair_color": "auburn, white",
#       "height": "182",
#       "homeworld": "http://swapi.dev/api/planets/20/",
#       "mass": "77",
#       "name": "Obi-Wan Kenobi",
#       "skin_color": "fair",
#       "species": [],
#       "starships": [
#         "http://swapi.dev/api/starships/48/",
#         "http://swapi.dev/api/starships/59/",
#         "http://swapi.dev/api/starships/64/",
#         "http://swapi.dev/api/starships/65/",
#         "http://swapi.dev/api/starships/74/"
#       ],
#       "url": "http://swapi.dev/api/people/10/",
#       "vehicles": [
#         "http://swapi.dev/api/vehicles/38/"
#       ]
#     }
#   ]
# }

# %%
#new lists to store character info
character_list = []
character_height = []
character_mass = []
character_species = []
character_first_movie = []
character_last_movie = []
character_number_movies = []
page = ["1", "2", "3", "4", "5", "6", "7", "8", "9"]
url_people_next = f"http://swapi.dev/api/people/?page="

for x in page:
    people_response_next = requests.get(url_people_next + x).json()
    
#for loop to list names
    for people in people_response_next["results"]:
        character_name = people["name"]
        character_list.append(character_name)
        
        height = people["height"]
        character_height.append(height)
        
        mass = people["mass"]
        character_mass.append(mass)
        
        char_species = people["species"]
        character_species.append(char_species)
        
        character_movie = people["films"][0]
        character_first_movie.append(character_movie)
        
        character_movie_last = people["films"][-1]
        character_last_movie.append(character_movie_last)
        
        character_movie_total = len(people["films"])
        character_number_movies.append(character_movie_total)
        print(f'{character_name} found!')
# Out:
# Luke Skywalker found!
# C-3PO found!
# R2-D2 found!
# Darth Vader found!
# Leia Organa found!
# Owen Lars found!
# Beru Whitesun lars found!
# R5-D4 found!
# Biggs Darklighter found!
# Obi-Wan Kenobi found!
# Anakin Skywalker found!
# Wilhuff Tarkin found!
# Chewbacca found!
# Han Solo found!
# Greedo found!
# Jabba Desilijic Tiure found!
# Wedge Antilles found!
# Jek Tono Porkins found!
# Yoda found!
# Palpatine found!
# Boba Fett found!
# IG-88 found!
# Bossk found!
# Lando Calrissian found!
# Lobot found!
# Ackbar found!
# Mon Mothma found!
# Arvel Crynyd found!
# Wicket Systri Warrick found!
# Nien Nunb found!
# Qui-Gon Jinn found!
# Nute Gunray found!
# Finis Valorum found!
# Padmé Amidala found!
# Jar Jar Binks found!
# Roos Tarpals found!
# Rugor Nass found!
# Ric Olié found!
# Watto found!
# Sebulba found!
# Quarsh Panaka found!
# Shmi Skywalker found!
# Darth Maul found!
# Bib Fortuna found!
# Ayla Secura found!
# Ratts Tyerel found!
# Dud Bolt found!
# Gasgano found!
# Ben Quadinaros found!
# Mace Windu found!
# Ki-Adi-Mundi found!
# Kit Fisto found!
# Eeth Koth found!
# Adi Gallia found!
# Saesee Tiin found!
# Yarael Poof found!
# Plo Koon found!
# Mas Amedda found!
# Gregar Typho found!
# Cordé found!
# Cliegg Lars found!
# Poggle the Lesser found!
# Luminara Unduli found!
# Barriss Offee found!
# Dormé found!
# Dooku found!
# Bail Prestor Organa found!
# Jango Fett found!
# Zam Wesell found!
# Dexter Jettster found!
# Lama Su found!
# Taun We found!
# Jocasta Nu found!
# R4-P17 found!
# Wat Tambor found!
# San Hill found!
# Shaak Ti found!
# Grievous found!
# Tarfful found!
# Raymus Antilles found!
# Sly Moore found!
# Tion Medon found!

# %%
#create new dataframe for all characters found with their data
characters_df = pd.DataFrame({"Character": character_list,
                              "Height": character_height,
                              "Mass": character_mass, 
                              "Species": character_species, 
                              "First Film": character_first_movie,
                              "Last Film": character_last_movie,
                              "Number of Film Appearances": character_number_movies})


characters_df.head(20)
# Out:
#                 Character Height     Mass                            Species  \
# 0          Luke Skywalker    172       77                                 []
# 1                   C-3PO    167       75  [http://swapi.dev/api/species/2/]
# 2                   R2-D2     96       32  [http://swapi.dev/api/species/2/]
# 3             Darth Vader    202      136                                 []
# 4             Leia Organa    150       49                                 []
# 5               Owen Lars    178      120                                 []
# 6      Beru Whitesun lars    165       75                                 []
# 7                   R5-D4     97       32  [http://swapi.dev/api/species/2/]
# 8       Biggs Darklighter    183       84                                 []
# 9          Obi-Wan Kenobi    182       77                                 []
# 10       Anakin Skywalker    188       84                                 []
# 11         Wilhuff Tarkin    180  unknown                                 []
# 12              Chewbacca    228      112  [http://swapi.dev/api/species/3/]
# 13               Han Solo    180       80                                 []
# 14                 Greedo    173       74  [http://swapi.dev/api/species/4/]
# 15  Jabba Desilijic Tiure    175    1,358  [http://swapi.dev/api/species/5/]
# 16         Wedge Antilles    170       77                                 []
# 17       Jek Tono Porkins    180      110                                 []
# 18                   Yoda     66       17  [http://swapi.dev/api/species/6/]
# 19              Palpatine    170       75                                 []
#
#                        First Film                      Last Film  \
# 0   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 1   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 2   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 3   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 4   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 5   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 6   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 7   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 8   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 9   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 10  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 11  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 12  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 13  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/3/
# 14  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 15  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/4/
# 16  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/3/
# 17  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 18  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/6/
# 19  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/6/
#
#     Number of Film Appearances
# 0                            4
# 1                            6
# 2                            6
# 3                            4
# 4                            4
# 5                            3
# 6                            3
# 7                            1
# 8                            1
# 9                            6
# 10                           3
# 11                           2
# 12                           4
# 13                           3
# 14                           1
# 15                           3
# 16                           3
# 17                           1
# 18                           5
# 19                           5

# %%
#drop characters that don't have a height or mass listed and create new dataframe for tracking purposes
cleaning_characters_df = characters_df.drop(characters_df[characters_df['Height'] == 'unknown'].index) 
cleaning_characters_df = characters_df.drop(characters_df[characters_df['Mass'] == 'unknown'].index) 

print(cleaning_characters_df.head(60))

#output to CSV to add missing Species [http://swapi.dev/api/species/1/: Human]
cleaning_characters_df.to_csv("csv_output/character_output.csv")
# Out:
#                 Character Height   Mass                             Species  \
# 0          Luke Skywalker    172     77                                  []
# 1                   C-3PO    167     75   [http://swapi.dev/api/species/2/]
# 2                   R2-D2     96     32   [http://swapi.dev/api/species/2/]
# 3             Darth Vader    202    136                                  []
# 4             Leia Organa    150     49                                  []
# 5               Owen Lars    178    120                                  []
# 6      Beru Whitesun lars    165     75                                  []
# 7                   R5-D4     97     32   [http://swapi.dev/api/species/2/]
# 8       Biggs Darklighter    183     84                                  []
# 9          Obi-Wan Kenobi    182     77                                  []
# 10       Anakin Skywalker    188     84                                  []
# 12              Chewbacca    228    112   [http://swapi.dev/api/species/3/]
# 13               Han Solo    180     80                                  []
# 14                 Greedo    173     74   [http://swapi.dev/api/species/4/]
# 15  Jabba Desilijic Tiure    175  1,358   [http://swapi.dev/api/species/5/]
# 16         Wedge Antilles    170     77                                  []
# 17       Jek Tono Porkins    180    110                                  []
# 18                   Yoda     66     17   [http://swapi.dev/api/species/6/]
# 19              Palpatine    170     75                                  []
# 20              Boba Fett    183   78.2                                  []
# 21                  IG-88    200    140   [http://swapi.dev/api/species/2/]
# 22                  Bossk    190    113   [http://swapi.dev/api/species/7/]
# 23       Lando Calrissian    177     79                                  []
# 24                  Lobot    175     79                                  []
# 25                 Ackbar    180     83   [http://swapi.dev/api/species/8/]
# 28  Wicket Systri Warrick     88     20   [http://swapi.dev/api/species/9/]
# 29              Nien Nunb    160     68  [http://swapi.dev/api/species/10/]
# 30           Qui-Gon Jinn    193     89                                  []
# 31            Nute Gunray    191     90  [http://swapi.dev/api/species/11/]
# 33          Padmé Amidala    185     45                                  []
# 34          Jar Jar Binks    196     66  [http://swapi.dev/api/species/12/]
# 35           Roos Tarpals    224     82  [http://swapi.dev/api/species/12/]
# 39                Sebulba    112     40  [http://swapi.dev/api/species/14/]
# 42             Darth Maul    175     80  [http://swapi.dev/api/species/22/]
# 44            Ayla Secura    178     55  [http://swapi.dev/api/species/15/]
# 45           Ratts Tyerel     79     15  [http://swapi.dev/api/species/16/]
# 46               Dud Bolt     94     45  [http://swapi.dev/api/species/17/]
# 48         Ben Quadinaros    163     65  [http://swapi.dev/api/species/19/]
# 49             Mace Windu    188     84                                  []
# 50           Ki-Adi-Mundi    198     82  [http://swapi.dev/api/species/20/]
# 51              Kit Fisto    196     87  [http://swapi.dev/api/species/21/]
# 53             Adi Gallia    184     50  [http://swapi.dev/api/species/23/]
# 56               Plo Koon    188     80  [http://swapi.dev/api/species/26/]
# 58           Gregar Typho    185     85                                  []
# 61      Poggle the Lesser    183     80  [http://swapi.dev/api/species/28/]
# 62        Luminara Unduli    170   56.2  [http://swapi.dev/api/species/29/]
# 63          Barriss Offee    166     50  [http://swapi.dev/api/species/29/]
# 65                  Dooku    193     80   [http://swapi.dev/api/species/1/]
# 67             Jango Fett    183     79                                  []
# 68             Zam Wesell    168     55  [http://swapi.dev/api/species/30/]
# 69        Dexter Jettster    198    102  [http://swapi.dev/api/species/31/]
# 70                Lama Su    229     88  [http://swapi.dev/api/species/32/]
# 74             Wat Tambor    193     48  [http://swapi.dev/api/species/33/]
# 76               Shaak Ti    178     57  [http://swapi.dev/api/species/35/]
# 77               Grievous    216    159  [http://swapi.dev/api/species/36/]
# 78                Tarfful    234    136   [http://swapi.dev/api/species/3/]
# 79        Raymus Antilles    188     79                                  []
# 80              Sly Moore    178     48                                  []
# 81             Tion Medon    206     80  [http://swapi.dev/api/species/37/]
#
#                        First Film                      Last Film  \
# 0   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 1   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 2   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 3   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 4   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 5   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 6   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 7   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 8   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 9   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 10  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 12  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 13  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/3/
# 14  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 15  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/4/
# 16  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/3/
# 17  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 18  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/6/
# 19  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/6/
# 20  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/5/
# 21  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/2/
# 22  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/2/
# 23  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/3/
# 24  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/2/
# 25  http://swapi.dev/api/films/3/  http://swapi.dev/api/films/3/
# 28  http://swapi.dev/api/films/3/  http://swapi.dev/api/films/3/
# 29  http://swapi.dev/api/films/3/  http://swapi.dev/api/films/3/
# 30  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 31  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 33  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 34  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/5/
# 35  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 39  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 42  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 44  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 45  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 46  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 48  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 49  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 50  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 51  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 53  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 56  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 58  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 61  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 62  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 63  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 65  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 67  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 68  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 69  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 70  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 74  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 76  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 77  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
# 78  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
# 79  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 80  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 81  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
#
#     Number of Film Appearances
# 0                            4
# 1                            6
# 2                            6
# 3                            4
# 4                            4
# 5                            3
# 6                            3
# 7                            1
# 8                            1
# 9                            6
# 10                           3
# 12                           4
# 13                           3
# 14                           1
# 15                           3
# 16                           3
# 17                           1
# 18                           5
# 19                           5
# 20                           3
# 21                           1
# 22                           1
# 23                           2
# 24                           1
# 25                           1
# 28                           1
# 29                           1
# 30                           1
# 31                           3
# 33                           3
# 34                           2
# 35                           1
# 39                           1
# 42                           1
# 44                           3
# 45                           1
# 46                           1
# 48                           1
# 49                           3
# 50                           3
# 51                           3
# 53                           2
# 56                           3
# 58                           1
# 61                           2
# 62                           2
# 63                           1
# 65                           2
# 67                           1
# 68                           1
# 69                           1
# 70                           1
# 74                           1
# 76                           2
# 77                           1
# 78                           1
# 79                           2
# 80                           2
# 81                           1

# %%
#input CSV with full Species values
cleaning_characters_df = pd.read_csv("csv_output/character_output_clean.csv")
#delete unnecessary column and clean values "1,358":1358 & "Jabba Desilijic Tiure" to "Jabba The Hutt"
del cleaning_characters_df['Unnamed: 0']
cleaning_characters_df=cleaning_characters_df.reset_index(drop=True)
#Manually cleaning Jabba's mass and name
cleaning_characters_df.iloc[[14],[2]]=1358
cleaning_characters_df.iloc[[14],[0]]="Jabba The Hutt"
cleaning_characters_df
# Out:
#                 Character  Height  Mass                               Species  \
# 0          Luke Skywalker     172    77   ['http://swapi.dev/api/species/1/']
# 1                   C-3PO     167    75   ['http://swapi.dev/api/species/2/']
# 2                   R2-D2      96    32   ['http://swapi.dev/api/species/2/']
# 3             Darth Vader     202   136   ['http://swapi.dev/api/species/1/']
# 4             Leia Organa     150    49   ['http://swapi.dev/api/species/1/']
# 5               Owen Lars     178   120   ['http://swapi.dev/api/species/1/']
# 6      Beru Whitesun lars     165    75   ['http://swapi.dev/api/species/1/']
# 7                   R5-D4      97    32   ['http://swapi.dev/api/species/2/']
# 8       Biggs Darklighter     183    84   ['http://swapi.dev/api/species/1/']
# 9          Obi-Wan Kenobi     182    77   ['http://swapi.dev/api/species/1/']
# 10       Anakin Skywalker     188    84   ['http://swapi.dev/api/species/1/']
# 11              Chewbacca     228   112   ['http://swapi.dev/api/species/3/']
# 12               Han Solo     180    80   ['http://swapi.dev/api/species/1/']
# 13                 Greedo     173    74   ['http://swapi.dev/api/species/4/']
# 14         Jabba The Hutt     175  1358   ['http://swapi.dev/api/species/5/']
# 15         Wedge Antilles     170    77   ['http://swapi.dev/api/species/1/']
# 16       Jek Tono Porkins     180   110   ['http://swapi.dev/api/species/1/']
# 17                   Yoda      66    17   ['http://swapi.dev/api/species/6/']
# 18              Palpatine     170    75   ['http://swapi.dev/api/species/1/']
# 19              Boba Fett     183  78.2   ['http://swapi.dev/api/species/1/']
# 20                  IG-88     200   140   ['http://swapi.dev/api/species/2/']
# 21                  Bossk     190   113   ['http://swapi.dev/api/species/7/']
# 22       Lando Calrissian     177    79   ['http://swapi.dev/api/species/1/']
# 23                  Lobot     175    79   ['http://swapi.dev/api/species/2/']
# 24                 Ackbar     180    83   ['http://swapi.dev/api/species/8/']
# 25  Wicket Systri Warrick      88    20   ['http://swapi.dev/api/species/9/']
# 26              Nien Nunb     160    68  ['http://swapi.dev/api/species/10/']
# 27           Qui-Gon Jinn     193    89   ['http://swapi.dev/api/species/1/']
# 28            Nute Gunray     191    90  ['http://swapi.dev/api/species/11/']
# 29          Padmé Amidala     185    45   ['http://swapi.dev/api/species/1/']
# 30          Jar Jar Binks     196    66  ['http://swapi.dev/api/species/12/']
# 31           Roos Tarpals     224    82  ['http://swapi.dev/api/species/12/']
# 32                Sebulba     112    40  ['http://swapi.dev/api/species/14/']
# 33             Darth Maul     175    80  ['http://swapi.dev/api/species/22/']
# 34            Ayla Secura     178    55  ['http://swapi.dev/api/species/15/']
# 35           Ratts Tyerel      79    15  ['http://swapi.dev/api/species/16/']
# 36               Dud Bolt      94    45  ['http://swapi.dev/api/species/17/']
# 37         Ben Quadinaros     163    65  ['http://swapi.dev/api/species/19/']
# 38             Mace Windu     188    84   ['http://swapi.dev/api/species/1/']
# 39           Ki-Adi-Mundi     198    82  ['http://swapi.dev/api/species/20/']
# 40              Kit Fisto     196    87  ['http://swapi.dev/api/species/21/']
# 41             Adi Gallia     184    50  ['http://swapi.dev/api/species/23/']
# 42               Plo Koon     188    80  ['http://swapi.dev/api/species/26/']
# 43           Gregar Typho     185    85   ['http://swapi.dev/api/species/1/']
# 44      Poggle the Lesser     183    80  ['http://swapi.dev/api/species/28/']
# 45        Luminara Unduli     170  56.2  ['http://swapi.dev/api/species/29/']
# 46          Barriss Offee     166    50  ['http://swapi.dev/api/species/29/']
# 47                  Dooku     193    80   ['http://swapi.dev/api/species/1/']
# 48             Jango Fett     183    79   ['http://swapi.dev/api/species/1/']
# 49             Zam Wesell     168    55  ['http://swapi.dev/api/species/30/']
# 50        Dexter Jettster     198   102  ['http://swapi.dev/api/species/31/']
# 51                Lama Su     229    88  ['http://swapi.dev/api/species/32/']
# 52             Wat Tambor     193    48  ['http://swapi.dev/api/species/33/']
# 53               Shaak Ti     178    57  ['http://swapi.dev/api/species/35/']
# 54               Grievous     216   159  ['http://swapi.dev/api/species/36/']
# 55                Tarfful     234   136   ['http://swapi.dev/api/species/3/']
# 56        Raymus Antilles     188    79   ['http://swapi.dev/api/species/1/']
# 57              Sly Moore     178    48   ['http://swapi.dev/api/species/1/']
# 58             Tion Medon     206    80  ['http://swapi.dev/api/species/37/']
#
#                        First Film                      Last Film  \
# 0   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 1   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 2   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 3   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 4   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 5   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 6   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 7   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 8   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 9   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 10  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 11  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 12  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/3/
# 13  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 14  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/4/
# 15  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/3/
# 16  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 17  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/6/
# 18  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/6/
# 19  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/5/
# 20  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/2/
# 21  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/2/
# 22  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/3/
# 23  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/2/
# 24  http://swapi.dev/api/films/3/  http://swapi.dev/api/films/3/
# 25  http://swapi.dev/api/films/3/  http://swapi.dev/api/films/3/
# 26  http://swapi.dev/api/films/3/  http://swapi.dev/api/films/3/
# 27  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 28  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 29  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 30  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/5/
# 31  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 32  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 33  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 34  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 35  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 36  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 37  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 38  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 39  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 40  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 41  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 42  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 43  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 44  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 45  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 46  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 47  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 48  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 49  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 50  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 51  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 52  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 53  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 54  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
# 55  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
# 56  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 57  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 58  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
#
#     Number of Film Appearances
# 0                            4
# 1                            6
# 2                            6
# 3                            4
# 4                            4
# 5                            3
# 6                            3
# 7                            1
# 8                            1
# 9                            6
# 10                           3
# 11                           4
# 12                           3
# 13                           1
# 14                           3
# 15                           3
# 16                           1
# 17                           5
# 18                           5
# 19                           3
# 20                           1
# 21                           1
# 22                           2
# 23                           1
# 24                           1
# 25                           1
# 26                           1
# 27                           1
# 28                           3
# 29                           3
# 30                           2
# 31                           1
# 32                           1
# 33                           1
# 34                           3
# 35                           1
# 36                           1
# 37                           1
# 38                           3
# 39                           3
# 40                           3
# 41                           2
# 42                           3
# 43                           1
# 44                           2
# 45                           2
# 46                           1
# 47                           2
# 48                           1
# 49                           1
# 50                           1
# 51                           1
# 52                           1
# 53                           2
# 54                           1
# 55                           1
# 56                           2
# 57                           2
# 58                           1

# %%
#remove [' '] from Species Column to prepare for merge
cleaning_characters_df['Species'] = cleaning_characters_df['Species'].str.replace("[","")
cleaning_characters_df['Species'] = cleaning_characters_df['Species'].str.replace("]","")
cleaning_characters_df['Species'] = cleaning_characters_df['Species'].str.replace("'","")
cleaning_characters_df.head()
# Out:
#         Character  Height Mass                          Species  \
# 0  Luke Skywalker     172   77  http://swapi.dev/api/species/1/
# 1           C-3PO     167   75  http://swapi.dev/api/species/2/
# 2           R2-D2      96   32  http://swapi.dev/api/species/2/
# 3     Darth Vader     202  136  http://swapi.dev/api/species/1/
# 4     Leia Organa     150   49  http://swapi.dev/api/species/1/
#
#                       First Film                      Last Film  \
# 0  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 1  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 2  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 3  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 4  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
#
#    Number of Film Appearances
# 0                           4
# 1                           6
# 2                           6
# 3                           4
# 4                           4

# %%
#Change "Species" column name to "URL" for merge (below after Species API pull)

cleaner_characters_df = cleaning_characters_df.rename(columns={"Species": "URL"})
cleaner_characters_df.head()
# Out:
#         Character  Height Mass                              URL  \
# 0  Luke Skywalker     172   77  http://swapi.dev/api/species/1/
# 1           C-3PO     167   75  http://swapi.dev/api/species/2/
# 2           R2-D2      96   32  http://swapi.dev/api/species/2/
# 3     Darth Vader     202  136  http://swapi.dev/api/species/1/
# 4     Leia Organa     150   49  http://swapi.dev/api/species/1/
#
#                       First Film                      Last Film  \
# 0  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 1  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 2  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 3  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 4  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
#
#    Number of Film Appearances
# 0                           4
# 1                           6
# 2                           6
# 3                           4
# 4                           4

# %%
#convert series to numeric for analysis
clean_char_height_series = pd.to_numeric(cleaner_characters_df["Height"])
clean_char_mass_series = pd.to_numeric(cleaner_characters_df["Mass"])

#dataframe to use as base template for all characters
clean_characters_df = pd.DataFrame({"Character": cleaner_characters_df["Character"],
                                 "Height": clean_char_height_series,
                                 "Mass": clean_char_mass_series,
                                 "URL": cleaner_characters_df["URL"], 
                                 "First Film": cleaner_characters_df["First Film"],
                                 "Last Film": cleaner_characters_df["Last Film"],
                                 "Number of Film Appearances": cleaner_characters_df["Number of Film Appearances"]})
clean_characters_df
# Out:
#                 Character  Height    Mass                               URL  \
# 0          Luke Skywalker     172    77.0   http://swapi.dev/api/species/1/
# 1                   C-3PO     167    75.0   http://swapi.dev/api/species/2/
# 2                   R2-D2      96    32.0   http://swapi.dev/api/species/2/
# 3             Darth Vader     202   136.0   http://swapi.dev/api/species/1/
# 4             Leia Organa     150    49.0   http://swapi.dev/api/species/1/
# 5               Owen Lars     178   120.0   http://swapi.dev/api/species/1/
# 6      Beru Whitesun lars     165    75.0   http://swapi.dev/api/species/1/
# 7                   R5-D4      97    32.0   http://swapi.dev/api/species/2/
# 8       Biggs Darklighter     183    84.0   http://swapi.dev/api/species/1/
# 9          Obi-Wan Kenobi     182    77.0   http://swapi.dev/api/species/1/
# 10       Anakin Skywalker     188    84.0   http://swapi.dev/api/species/1/
# 11              Chewbacca     228   112.0   http://swapi.dev/api/species/3/
# 12               Han Solo     180    80.0   http://swapi.dev/api/species/1/
# 13                 Greedo     173    74.0   http://swapi.dev/api/species/4/
# 14         Jabba The Hutt     175  1358.0   http://swapi.dev/api/species/5/
# 15         Wedge Antilles     170    77.0   http://swapi.dev/api/species/1/
# 16       Jek Tono Porkins     180   110.0   http://swapi.dev/api/species/1/
# 17                   Yoda      66    17.0   http://swapi.dev/api/species/6/
# 18              Palpatine     170    75.0   http://swapi.dev/api/species/1/
# 19              Boba Fett     183    78.2   http://swapi.dev/api/species/1/
# 20                  IG-88     200   140.0   http://swapi.dev/api/species/2/
# 21                  Bossk     190   113.0   http://swapi.dev/api/species/7/
# 22       Lando Calrissian     177    79.0   http://swapi.dev/api/species/1/
# 23                  Lobot     175    79.0   http://swapi.dev/api/species/2/
# 24                 Ackbar     180    83.0   http://swapi.dev/api/species/8/
# 25  Wicket Systri Warrick      88    20.0   http://swapi.dev/api/species/9/
# 26              Nien Nunb     160    68.0  http://swapi.dev/api/species/10/
# 27           Qui-Gon Jinn     193    89.0   http://swapi.dev/api/species/1/
# 28            Nute Gunray     191    90.0  http://swapi.dev/api/species/11/
# 29          Padmé Amidala     185    45.0   http://swapi.dev/api/species/1/
# 30          Jar Jar Binks     196    66.0  http://swapi.dev/api/species/12/
# 31           Roos Tarpals     224    82.0  http://swapi.dev/api/species/12/
# 32                Sebulba     112    40.0  http://swapi.dev/api/species/14/
# 33             Darth Maul     175    80.0  http://swapi.dev/api/species/22/
# 34            Ayla Secura     178    55.0  http://swapi.dev/api/species/15/
# 35           Ratts Tyerel      79    15.0  http://swapi.dev/api/species/16/
# 36               Dud Bolt      94    45.0  http://swapi.dev/api/species/17/
# 37         Ben Quadinaros     163    65.0  http://swapi.dev/api/species/19/
# 38             Mace Windu     188    84.0   http://swapi.dev/api/species/1/
# 39           Ki-Adi-Mundi     198    82.0  http://swapi.dev/api/species/20/
# 40              Kit Fisto     196    87.0  http://swapi.dev/api/species/21/
# 41             Adi Gallia     184    50.0  http://swapi.dev/api/species/23/
# 42               Plo Koon     188    80.0  http://swapi.dev/api/species/26/
# 43           Gregar Typho     185    85.0   http://swapi.dev/api/species/1/
# 44      Poggle the Lesser     183    80.0  http://swapi.dev/api/species/28/
# 45        Luminara Unduli     170    56.2  http://swapi.dev/api/species/29/
# 46          Barriss Offee     166    50.0  http://swapi.dev/api/species/29/
# 47                  Dooku     193    80.0   http://swapi.dev/api/species/1/
# 48             Jango Fett     183    79.0   http://swapi.dev/api/species/1/
# 49             Zam Wesell     168    55.0  http://swapi.dev/api/species/30/
# 50        Dexter Jettster     198   102.0  http://swapi.dev/api/species/31/
# 51                Lama Su     229    88.0  http://swapi.dev/api/species/32/
# 52             Wat Tambor     193    48.0  http://swapi.dev/api/species/33/
# 53               Shaak Ti     178    57.0  http://swapi.dev/api/species/35/
# 54               Grievous     216   159.0  http://swapi.dev/api/species/36/
# 55                Tarfful     234   136.0   http://swapi.dev/api/species/3/
# 56        Raymus Antilles     188    79.0   http://swapi.dev/api/species/1/
# 57              Sly Moore     178    48.0   http://swapi.dev/api/species/1/
# 58             Tion Medon     206    80.0  http://swapi.dev/api/species/37/
#
#                        First Film                      Last Film  \
# 0   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 1   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 2   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 3   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 4   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 5   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 6   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 7   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 8   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 9   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 10  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 11  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 12  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/3/
# 13  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 14  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/4/
# 15  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/3/
# 16  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/1/
# 17  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/6/
# 18  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/6/
# 19  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/5/
# 20  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/2/
# 21  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/2/
# 22  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/3/
# 23  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/2/
# 24  http://swapi.dev/api/films/3/  http://swapi.dev/api/films/3/
# 25  http://swapi.dev/api/films/3/  http://swapi.dev/api/films/3/
# 26  http://swapi.dev/api/films/3/  http://swapi.dev/api/films/3/
# 27  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 28  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 29  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 30  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/5/
# 31  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 32  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 33  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 34  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 35  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 36  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 37  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 38  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 39  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 40  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 41  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 42  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/6/
# 43  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 44  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 45  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 46  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 47  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 48  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 49  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 50  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 51  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 52  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 53  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 54  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
# 55  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
# 56  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 57  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/6/
# 58  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
#
#     Number of Film Appearances
# 0                            4
# 1                            6
# 2                            6
# 3                            4
# 4                            4
# 5                            3
# 6                            3
# 7                            1
# 8                            1
# 9                            6
# 10                           3
# 11                           4
# 12                           3
# 13                           1
# 14                           3
# 15                           3
# 16                           1
# 17                           5
# 18                           5
# 19                           3
# 20                           1
# 21                           1
# 22                           2
# 23                           1
# 24                           1
# 25                           1
# 26                           1
# 27                           1
# 28                           3
# 29                           3
# 30                           2
# 31                           1
# 32                           1
# 33                           1
# 34                           3
# 35                           1
# 36                           1
# 37                           1
# 38                           3
# 39                           3
# 40                           3
# 41                           2
# 42                           3
# 43                           1
# 44                           2
# 45                           2
# 46                           1
# 47                           2
# 48                           1
# 49                           1
# 50                           1
# 51                           1
# 52                           1
# 53                           2
# 54                           1
# 55                           1
# 56                           2
# 57                           2
# 58                           1

# %%
#create lists to store species data
species_types = []
species_avg_height = []
species_avg_life = []
species_classification = []
species_designation = []
species_url_list = []
#page iterator & url
page = ["1", "2", "3", "4"]
find_species_url = f"http://swapi.dev/api/species/?page="

for x in page:
    find_species_response = requests.get(find_species_url + x).json()
    
#for loop to list names in films
    for species in find_species_response["results"]:
        species_name = species["name"]
        species_types.append(species_name)
        species_height = species["average_height"]
        species_avg_height.append(species_height)
        species_life = species["average_lifespan"]
        species_avg_life.append(species_life)
        species_class = species["classification"]
        species_classification.append(species_class)
        species_design = species["designation"]
        species_designation.append(species_design)
        species_url = species["url"]
        species_url_list.append(species_url)
        print(f'{species_name} found!')
# Out:
# Human found!
# Droid found!
# Wookie found!
# Rodian found!
# Hutt found!
# Yoda's species found!
# Trandoshan found!
# Mon Calamari found!
# Ewok found!
# Sullustan found!
# Neimodian found!
# Gungan found!
# Toydarian found!
# Dug found!
# Twi'lek found!
# Aleena found!
# Vulptereen found!
# Xexto found!
# Toong found!
# Cerean found!
# Nautolan found!
# Zabrak found!
# Tholothian found!
# Iktotchi found!
# Quermian found!
# Kel Dor found!
# Chagrian found!
# Geonosian found!
# Mirialan found!
# Clawdite found!
# Besalisk found!
# Kaminoan found!
# Skakoan found!
# Muun found!
# Togruta found!
# Kaleesh found!
# Pau'an found!

# %%
#create new dataframe for all Species found
species_df = pd.DataFrame({"Species": species_types,
                           "Average Height": species_avg_height,
                           "URL": species_url_list})
print(species_df)
# Out:
#            Species Average Height                               URL
# 0            Human            180   http://swapi.dev/api/species/1/
# 1            Droid            n/a   http://swapi.dev/api/species/2/
# 2           Wookie            210   http://swapi.dev/api/species/3/
# 3           Rodian            170   http://swapi.dev/api/species/4/
# 4             Hutt            300   http://swapi.dev/api/species/5/
# 5   Yoda's species             66   http://swapi.dev/api/species/6/
# 6       Trandoshan            200   http://swapi.dev/api/species/7/
# 7     Mon Calamari            160   http://swapi.dev/api/species/8/
# 8             Ewok            100   http://swapi.dev/api/species/9/
# 9        Sullustan            180  http://swapi.dev/api/species/10/
# 10       Neimodian            180  http://swapi.dev/api/species/11/
# 11          Gungan            190  http://swapi.dev/api/species/12/
# 12       Toydarian            120  http://swapi.dev/api/species/13/
# 13             Dug            100  http://swapi.dev/api/species/14/
# 14         Twi'lek            200  http://swapi.dev/api/species/15/
# 15          Aleena             80  http://swapi.dev/api/species/16/
# 16      Vulptereen            100  http://swapi.dev/api/species/17/
# 17           Xexto            125  http://swapi.dev/api/species/18/
# 18           Toong            200  http://swapi.dev/api/species/19/
# 19          Cerean            200  http://swapi.dev/api/species/20/
# 20        Nautolan            180  http://swapi.dev/api/species/21/
# 21          Zabrak            180  http://swapi.dev/api/species/22/
# 22      Tholothian        unknown  http://swapi.dev/api/species/23/
# 23        Iktotchi            180  http://swapi.dev/api/species/24/
# 24        Quermian            240  http://swapi.dev/api/species/25/
# 25         Kel Dor            180  http://swapi.dev/api/species/26/
# 26        Chagrian            190  http://swapi.dev/api/species/27/
# 27       Geonosian            178  http://swapi.dev/api/species/28/
# 28        Mirialan            180  http://swapi.dev/api/species/29/
# 29        Clawdite            180  http://swapi.dev/api/species/30/
# 30        Besalisk            178  http://swapi.dev/api/species/31/
# 31        Kaminoan            220  http://swapi.dev/api/species/32/
# 32         Skakoan        unknown  http://swapi.dev/api/species/33/
# 33            Muun            190  http://swapi.dev/api/species/34/
# 34         Togruta            180  http://swapi.dev/api/species/35/
# 35         Kaleesh            170  http://swapi.dev/api/species/36/
# 36          Pau'an            190  http://swapi.dev/api/species/37/

# %%
#drop unknown & n/a value and reset index new species list and heights
cleaning_species_df = species_df.drop(species_df[species_df['Average Height'] == 'unknown'].index) 
cleaner_species_df = cleaning_species_df.drop(cleaning_species_df[cleaning_species_df['Average Height'] == 'n/a'].index) 
cleaner_species_df = cleaner_species_df.reset_index(drop=True)
cleaner_species_df
# Out:
#            Species Average Height                               URL
# 0            Human            180   http://swapi.dev/api/species/1/
# 1           Wookie            210   http://swapi.dev/api/species/3/
# 2           Rodian            170   http://swapi.dev/api/species/4/
# 3             Hutt            300   http://swapi.dev/api/species/5/
# 4   Yoda's species             66   http://swapi.dev/api/species/6/
# 5       Trandoshan            200   http://swapi.dev/api/species/7/
# 6     Mon Calamari            160   http://swapi.dev/api/species/8/
# 7             Ewok            100   http://swapi.dev/api/species/9/
# 8        Sullustan            180  http://swapi.dev/api/species/10/
# 9        Neimodian            180  http://swapi.dev/api/species/11/
# 10          Gungan            190  http://swapi.dev/api/species/12/
# 11       Toydarian            120  http://swapi.dev/api/species/13/
# 12             Dug            100  http://swapi.dev/api/species/14/
# 13         Twi'lek            200  http://swapi.dev/api/species/15/
# 14          Aleena             80  http://swapi.dev/api/species/16/
# 15      Vulptereen            100  http://swapi.dev/api/species/17/
# 16           Xexto            125  http://swapi.dev/api/species/18/
# 17           Toong            200  http://swapi.dev/api/species/19/
# 18          Cerean            200  http://swapi.dev/api/species/20/
# 19        Nautolan            180  http://swapi.dev/api/species/21/
# 20          Zabrak            180  http://swapi.dev/api/species/22/
# 21        Iktotchi            180  http://swapi.dev/api/species/24/
# 22        Quermian            240  http://swapi.dev/api/species/25/
# 23         Kel Dor            180  http://swapi.dev/api/species/26/
# 24        Chagrian            190  http://swapi.dev/api/species/27/
# 25       Geonosian            178  http://swapi.dev/api/species/28/
# 26        Mirialan            180  http://swapi.dev/api/species/29/
# 27        Clawdite            180  http://swapi.dev/api/species/30/
# 28        Besalisk            178  http://swapi.dev/api/species/31/
# 29        Kaminoan            220  http://swapi.dev/api/species/32/
# 30            Muun            190  http://swapi.dev/api/species/34/
# 31         Togruta            180  http://swapi.dev/api/species/35/
# 32         Kaleesh            170  http://swapi.dev/api/species/36/
# 33          Pau'an            190  http://swapi.dev/api/species/37/

# %%
cleaner_species_series = pd.to_numeric(cleaner_species_df["Average Height"])
cleaner_species_series
clean_species_df = pd.DataFrame({"Species": cleaner_species_df["Species"],
                                 "Average Height": cleaner_species_series,
                                 "URL": cleaner_species_df["URL"]})
clean_species_df = clean_species_df.sort_values(["Average Height"], ascending=True)
clean_species_df = clean_species_df.reset_index(drop=True)
clean_species_df
# Out:
#            Species  Average Height                               URL
# 0   Yoda's species              66   http://swapi.dev/api/species/6/
# 1           Aleena              80  http://swapi.dev/api/species/16/
# 2       Vulptereen             100  http://swapi.dev/api/species/17/
# 3             Ewok             100   http://swapi.dev/api/species/9/
# 4              Dug             100  http://swapi.dev/api/species/14/
# 5        Toydarian             120  http://swapi.dev/api/species/13/
# 6            Xexto             125  http://swapi.dev/api/species/18/
# 7     Mon Calamari             160   http://swapi.dev/api/species/8/
# 8          Kaleesh             170  http://swapi.dev/api/species/36/
# 9           Rodian             170   http://swapi.dev/api/species/4/
# 10       Geonosian             178  http://swapi.dev/api/species/28/
# 11        Besalisk             178  http://swapi.dev/api/species/31/
# 12          Zabrak             180  http://swapi.dev/api/species/22/
# 13        Mirialan             180  http://swapi.dev/api/species/29/
# 14        Iktotchi             180  http://swapi.dev/api/species/24/
# 15        Clawdite             180  http://swapi.dev/api/species/30/
# 16         Togruta             180  http://swapi.dev/api/species/35/
# 17         Kel Dor             180  http://swapi.dev/api/species/26/
# 18        Nautolan             180  http://swapi.dev/api/species/21/
# 19           Human             180   http://swapi.dev/api/species/1/
# 20       Neimodian             180  http://swapi.dev/api/species/11/
# 21       Sullustan             180  http://swapi.dev/api/species/10/
# 22          Gungan             190  http://swapi.dev/api/species/12/
# 23        Chagrian             190  http://swapi.dev/api/species/27/
# 24            Muun             190  http://swapi.dev/api/species/34/
# 25          Pau'an             190  http://swapi.dev/api/species/37/
# 26           Toong             200  http://swapi.dev/api/species/19/
# 27         Twi'lek             200  http://swapi.dev/api/species/15/
# 28      Trandoshan             200   http://swapi.dev/api/species/7/
# 29          Cerean             200  http://swapi.dev/api/species/20/
# 30          Wookie             210   http://swapi.dev/api/species/3/
# 31        Kaminoan             220  http://swapi.dev/api/species/32/
# 32        Quermian             240  http://swapi.dev/api/species/25/
# 33            Hutt             300   http://swapi.dev/api/species/5/

# %% [markdown]
# # Characters, Species & Films Merge

# %%
#inserting merged DF with species labels for characters and average heights for species
merged_characters_species_df = pd.merge(clean_characters_df, species_df, on="URL", how="left")
merged_characters_species_df = merged_characters_species_df.drop(columns=(["URL"]))
#drop unknowns and n/a
cleaning_merged_characters_species_df = merged_characters_species_df.drop(merged_characters_species_df[merged_characters_species_df['Average Height'] == 'unknown'].index) 
cleaning_merged_characters_species_df = cleaning_merged_characters_species_df.drop(cleaning_merged_characters_species_df[cleaning_merged_characters_species_df['Average Height'] == 'n/a'].index)
cleaning_merged_characters_species_df.head(10)
# Out:
#              Character  Height   Mass                     First Film  \
# 0       Luke Skywalker     172   77.0  http://swapi.dev/api/films/1/
# 3          Darth Vader     202  136.0  http://swapi.dev/api/films/1/
# 4          Leia Organa     150   49.0  http://swapi.dev/api/films/1/
# 5            Owen Lars     178  120.0  http://swapi.dev/api/films/1/
# 6   Beru Whitesun lars     165   75.0  http://swapi.dev/api/films/1/
# 8    Biggs Darklighter     183   84.0  http://swapi.dev/api/films/1/
# 9       Obi-Wan Kenobi     182   77.0  http://swapi.dev/api/films/1/
# 10    Anakin Skywalker     188   84.0  http://swapi.dev/api/films/4/
# 11           Chewbacca     228  112.0  http://swapi.dev/api/films/1/
# 12            Han Solo     180   80.0  http://swapi.dev/api/films/1/
#
#                         Last Film  Number of Film Appearances Species  \
# 0   http://swapi.dev/api/films/6/                           4   Human
# 3   http://swapi.dev/api/films/6/                           4   Human
# 4   http://swapi.dev/api/films/6/                           4   Human
# 5   http://swapi.dev/api/films/6/                           3   Human
# 6   http://swapi.dev/api/films/6/                           3   Human
# 8   http://swapi.dev/api/films/1/                           1   Human
# 9   http://swapi.dev/api/films/6/                           6   Human
# 10  http://swapi.dev/api/films/6/                           3   Human
# 11  http://swapi.dev/api/films/6/                           4  Wookie
# 12  http://swapi.dev/api/films/3/                           3   Human
#
#    Average Height
# 0             180
# 3             180
# 4             180
# 5             180
# 6             180
# 8             180
# 9             180
# 10            180
# 11            210
# 12            180

# %%
#create new series with numerical data
average_height_series = pd.to_numeric(cleaning_merged_characters_species_df["Average Height"])
film_appearances_series = pd.to_numeric(cleaning_merged_characters_species_df["Number of Film Appearances"])
#create new dataframe to hold cleaner data
clean_merged_characters_species_df = pd.DataFrame({"Character": cleaning_merged_characters_species_df["Character"],
                                                   "Height": cleaning_merged_characters_species_df["Height"],
                                                   "Mass": cleaning_merged_characters_species_df["Mass"],
                                                   "Species": cleaning_merged_characters_species_df["Species"],
                                                   "Average Species Height": average_height_series,
                                                   "First Film": cleaning_merged_characters_species_df["First Film"],
                                                   "Last Film": cleaning_merged_characters_species_df["Last Film"],
                                                   "Number of Film Appearances": film_appearances_series})
#sort by Height
clean_merged_characters_species_df = clean_merged_characters_species_df.sort_values(["Height"])
clean_merged_characters_species_df = clean_merged_characters_species_df.reset_index(drop=True)
clean_merged_characters_species_df
# Out:
#                 Character  Height    Mass         Species  \
# 0                    Yoda      66    17.0  Yoda's species
# 1            Ratts Tyerel      79    15.0          Aleena
# 2   Wicket Systri Warrick      88    20.0            Ewok
# 3                Dud Bolt      94    45.0      Vulptereen
# 4                 Sebulba     112    40.0             Dug
# 5             Leia Organa     150    49.0           Human
# 6               Nien Nunb     160    68.0       Sullustan
# 7          Ben Quadinaros     163    65.0           Toong
# 8      Beru Whitesun lars     165    75.0           Human
# 9           Barriss Offee     166    50.0        Mirialan
# 10             Zam Wesell     168    55.0        Clawdite
# 11         Wedge Antilles     170    77.0           Human
# 12        Luminara Unduli     170    56.2        Mirialan
# 13              Palpatine     170    75.0           Human
# 14         Luke Skywalker     172    77.0           Human
# 15                 Greedo     173    74.0          Rodian
# 16             Darth Maul     175    80.0          Zabrak
# 17         Jabba The Hutt     175  1358.0            Hutt
# 18       Lando Calrissian     177    79.0           Human
# 19              Owen Lars     178   120.0           Human
# 20            Ayla Secura     178    55.0         Twi'lek
# 21               Shaak Ti     178    57.0         Togruta
# 22              Sly Moore     178    48.0           Human
# 23               Han Solo     180    80.0           Human
# 24       Jek Tono Porkins     180   110.0           Human
# 25                 Ackbar     180    83.0    Mon Calamari
# 26         Obi-Wan Kenobi     182    77.0           Human
# 27              Boba Fett     183    78.2           Human
# 28      Biggs Darklighter     183    84.0           Human
# 29      Poggle the Lesser     183    80.0       Geonosian
# 30             Jango Fett     183    79.0           Human
# 31          Padmé Amidala     185    45.0           Human
# 32           Gregar Typho     185    85.0           Human
# 33       Anakin Skywalker     188    84.0           Human
# 34        Raymus Antilles     188    79.0           Human
# 35             Mace Windu     188    84.0           Human
# 36               Plo Koon     188    80.0         Kel Dor
# 37                  Bossk     190   113.0      Trandoshan
# 38            Nute Gunray     191    90.0       Neimodian
# 39           Qui-Gon Jinn     193    89.0           Human
# 40                  Dooku     193    80.0           Human
# 41          Jar Jar Binks     196    66.0          Gungan
# 42              Kit Fisto     196    87.0        Nautolan
# 43           Ki-Adi-Mundi     198    82.0          Cerean
# 44        Dexter Jettster     198   102.0        Besalisk
# 45            Darth Vader     202   136.0           Human
# 46             Tion Medon     206    80.0          Pau'an
# 47               Grievous     216   159.0         Kaleesh
# 48           Roos Tarpals     224    82.0          Gungan
# 49              Chewbacca     228   112.0          Wookie
# 50                Lama Su     229    88.0        Kaminoan
# 51                Tarfful     234   136.0          Wookie
#
#     Average Species Height                     First Film  \
# 0                       66  http://swapi.dev/api/films/2/
# 1                       80  http://swapi.dev/api/films/4/
# 2                      100  http://swapi.dev/api/films/3/
# 3                      100  http://swapi.dev/api/films/4/
# 4                      100  http://swapi.dev/api/films/4/
# 5                      180  http://swapi.dev/api/films/1/
# 6                      180  http://swapi.dev/api/films/3/
# 7                      200  http://swapi.dev/api/films/4/
# 8                      180  http://swapi.dev/api/films/1/
# 9                      180  http://swapi.dev/api/films/5/
# 10                     180  http://swapi.dev/api/films/5/
# 11                     180  http://swapi.dev/api/films/1/
# 12                     180  http://swapi.dev/api/films/5/
# 13                     180  http://swapi.dev/api/films/2/
# 14                     180  http://swapi.dev/api/films/1/
# 15                     170  http://swapi.dev/api/films/1/
# 16                     180  http://swapi.dev/api/films/4/
# 17                     300  http://swapi.dev/api/films/1/
# 18                     180  http://swapi.dev/api/films/2/
# 19                     180  http://swapi.dev/api/films/1/
# 20                     200  http://swapi.dev/api/films/4/
# 21                     180  http://swapi.dev/api/films/5/
# 22                     180  http://swapi.dev/api/films/5/
# 23                     180  http://swapi.dev/api/films/1/
# 24                     180  http://swapi.dev/api/films/1/
# 25                     160  http://swapi.dev/api/films/3/
# 26                     180  http://swapi.dev/api/films/1/
# 27                     180  http://swapi.dev/api/films/2/
# 28                     180  http://swapi.dev/api/films/1/
# 29                     178  http://swapi.dev/api/films/5/
# 30                     180  http://swapi.dev/api/films/5/
# 31                     180  http://swapi.dev/api/films/4/
# 32                     180  http://swapi.dev/api/films/5/
# 33                     180  http://swapi.dev/api/films/4/
# 34                     180  http://swapi.dev/api/films/1/
# 35                     180  http://swapi.dev/api/films/4/
# 36                     180  http://swapi.dev/api/films/4/
# 37                     200  http://swapi.dev/api/films/2/
# 38                     180  http://swapi.dev/api/films/4/
# 39                     180  http://swapi.dev/api/films/4/
# 40                     180  http://swapi.dev/api/films/5/
# 41                     190  http://swapi.dev/api/films/4/
# 42                     180  http://swapi.dev/api/films/4/
# 43                     200  http://swapi.dev/api/films/4/
# 44                     178  http://swapi.dev/api/films/5/
# 45                     180  http://swapi.dev/api/films/1/
# 46                     190  http://swapi.dev/api/films/6/
# 47                     170  http://swapi.dev/api/films/6/
# 48                     190  http://swapi.dev/api/films/4/
# 49                     210  http://swapi.dev/api/films/1/
# 50                     220  http://swapi.dev/api/films/5/
# 51                     210  http://swapi.dev/api/films/6/
#
#                         Last Film  Number of Film Appearances
# 0   http://swapi.dev/api/films/6/                           5
# 1   http://swapi.dev/api/films/4/                           1
# 2   http://swapi.dev/api/films/3/                           1
# 3   http://swapi.dev/api/films/4/                           1
# 4   http://swapi.dev/api/films/4/                           1
# 5   http://swapi.dev/api/films/6/                           4
# 6   http://swapi.dev/api/films/3/                           1
# 7   http://swapi.dev/api/films/4/                           1
# 8   http://swapi.dev/api/films/6/                           3
# 9   http://swapi.dev/api/films/5/                           1
# 10  http://swapi.dev/api/films/5/                           1
# 11  http://swapi.dev/api/films/3/                           3
# 12  http://swapi.dev/api/films/6/                           2
# 13  http://swapi.dev/api/films/6/                           5
# 14  http://swapi.dev/api/films/6/                           4
# 15  http://swapi.dev/api/films/1/                           1
# 16  http://swapi.dev/api/films/4/                           1
# 17  http://swapi.dev/api/films/4/                           3
# 18  http://swapi.dev/api/films/3/                           2
# 19  http://swapi.dev/api/films/6/                           3
# 20  http://swapi.dev/api/films/6/                           3
# 21  http://swapi.dev/api/films/6/                           2
# 22  http://swapi.dev/api/films/6/                           2
# 23  http://swapi.dev/api/films/3/                           3
# 24  http://swapi.dev/api/films/1/                           1
# 25  http://swapi.dev/api/films/3/                           1
# 26  http://swapi.dev/api/films/6/                           6
# 27  http://swapi.dev/api/films/5/                           3
# 28  http://swapi.dev/api/films/1/                           1
# 29  http://swapi.dev/api/films/6/                           2
# 30  http://swapi.dev/api/films/5/                           1
# 31  http://swapi.dev/api/films/6/                           3
# 32  http://swapi.dev/api/films/5/                           1
# 33  http://swapi.dev/api/films/6/                           3
# 34  http://swapi.dev/api/films/6/                           2
# 35  http://swapi.dev/api/films/6/                           3
# 36  http://swapi.dev/api/films/6/                           3
# 37  http://swapi.dev/api/films/2/                           1
# 38  http://swapi.dev/api/films/6/                           3
# 39  http://swapi.dev/api/films/4/                           1
# 40  http://swapi.dev/api/films/6/                           2
# 41  http://swapi.dev/api/films/5/                           2
# 42  http://swapi.dev/api/films/6/                           3
# 43  http://swapi.dev/api/films/6/                           3
# 44  http://swapi.dev/api/films/5/                           1
# 45  http://swapi.dev/api/films/6/                           4
# 46  http://swapi.dev/api/films/6/                           1
# 47  http://swapi.dev/api/films/6/                           1
# 48  http://swapi.dev/api/films/4/                           1
# 49  http://swapi.dev/api/films/6/                           4
# 50  http://swapi.dev/api/films/5/                           1
# 51  http://swapi.dev/api/films/6/                           1

# %%
#modify film dataframe to prepare for merge
films_first_adjusted_df = films_df.rename(columns={"URL": "First Film"})
films_first_adjusted_df = films_first_adjusted_df.drop(columns=(["Episode ID"]))
films_first_adjusted_df = films_first_adjusted_df.drop(columns=(["Release Date"]))
films_first_adjusted_df
# Out:
#                      Title                     First Film  \
# 0               A New Hope  http://swapi.dev/api/films/1/
# 1  The Empire Strikes Back  http://swapi.dev/api/films/2/
# 2       Return of the Jedi  http://swapi.dev/api/films/3/
# 3       The Phantom Menace  http://swapi.dev/api/films/4/
# 4     Attack of the Clones  http://swapi.dev/api/films/5/
# 5      Revenge of the Sith  http://swapi.dev/api/films/6/
#
#    Number of Characters  Number of Species  Number of Planets  \
# 0                    18                  5                  3
# 1                    16                  5                  4
# 2                    20                  9                  5
# 3                    34                 20                  3
# 4                    40                 14                  5
# 5                    34                 20                 13
#
#    Number of Vehicles  Number of Starships
# 0                   4                    8
# 1                   6                    9
# 2                   8                   12
# 3                   7                    5
# 4                  11                    9
# 5                  13                   12

# %%
#merge modified film dataframe with clean_merged_characters_species_df
merged_characters_species_film_df = pd.merge(clean_merged_characters_species_df, films_first_adjusted_df, on="First Film", how="left")
merged_characters_species_film_df = merged_characters_species_film_df.drop(columns=(["First Film"]))
#rename column 
merged_characters_species_film_df = merged_characters_species_film_df.rename(columns={"Title":"First Film Appearance"})
merged_characters_species_film_df.head()
# Out:
#                Character  Height  Mass         Species  \
# 0                   Yoda      66  17.0  Yoda's species
# 1           Ratts Tyerel      79  15.0          Aleena
# 2  Wicket Systri Warrick      88  20.0            Ewok
# 3               Dud Bolt      94  45.0      Vulptereen
# 4                Sebulba     112  40.0             Dug
#
#    Average Species Height                      Last Film  \
# 0                      66  http://swapi.dev/api/films/6/
# 1                      80  http://swapi.dev/api/films/4/
# 2                     100  http://swapi.dev/api/films/3/
# 3                     100  http://swapi.dev/api/films/4/
# 4                     100  http://swapi.dev/api/films/4/
#
#    Number of Film Appearances    First Film Appearance  Number of Characters  \
# 0                           5  The Empire Strikes Back                    16
# 1                           1       The Phantom Menace                    34
# 2                           1       Return of the Jedi                    20
# 3                           1       The Phantom Menace                    34
# 4                           1       The Phantom Menace                    34
#
#    Number of Species  Number of Planets  Number of Vehicles  \
# 0                  5                  4                   6
# 1                 20                  3                   7
# 2                  9                  5                   8
# 3                 20                  3                   7
# 4                 20                  3                   7
#
#    Number of Starships
# 0                    9
# 1                    5
# 2                   12
# 3                    5
# 4                    5

# %%
# modify film df for merge to fix "Last Film" column
films_last_adjusted_df = films_first_adjusted_df.rename(columns={"First Film":"Last Film"})
films_last_adjusted_df
# Out:
#                      Title                      Last Film  \
# 0               A New Hope  http://swapi.dev/api/films/1/
# 1  The Empire Strikes Back  http://swapi.dev/api/films/2/
# 2       Return of the Jedi  http://swapi.dev/api/films/3/
# 3       The Phantom Menace  http://swapi.dev/api/films/4/
# 4     Attack of the Clones  http://swapi.dev/api/films/5/
# 5      Revenge of the Sith  http://swapi.dev/api/films/6/
#
#    Number of Characters  Number of Species  Number of Planets  \
# 0                    18                  5                  3
# 1                    16                  5                  4
# 2                    20                  9                  5
# 3                    34                 20                  3
# 4                    40                 14                  5
# 5                    34                 20                 13
#
#    Number of Vehicles  Number of Starships
# 0                   4                    8
# 1                   6                    9
# 2                   8                   12
# 3                   7                    5
# 4                  11                    9
# 5                  13                   12

# %% [markdown]
# # Merged FINAL Character Dataframe

# %%
#merge modified "last film" df into dataframe and clean it up
clean_merged_characters_species_film_df = pd.merge(merged_characters_species_film_df, films_last_adjusted_df, on="Last Film", how="right")
clean_merged_characters_species_film_df = clean_merged_characters_species_film_df.drop(columns=("Last Film"))
clean_merged_characters_species_film_df = clean_merged_characters_species_film_df.rename(columns={"Title":"Last Film Appearance"})
clean_merged_characters_species_film_df
# Out:
#                 Character  Height    Mass         Species  \
# 0                    Yoda      66    17.0  Yoda's species
# 1             Leia Organa     150    49.0           Human
# 2      Beru Whitesun lars     165    75.0           Human
# 3         Luminara Unduli     170    56.2        Mirialan
# 4               Palpatine     170    75.0           Human
# 5          Luke Skywalker     172    77.0           Human
# 6               Owen Lars     178   120.0           Human
# 7             Ayla Secura     178    55.0         Twi'lek
# 8                Shaak Ti     178    57.0         Togruta
# 9               Sly Moore     178    48.0           Human
# 10         Obi-Wan Kenobi     182    77.0           Human
# 11      Poggle the Lesser     183    80.0       Geonosian
# 12          Padmé Amidala     185    45.0           Human
# 13       Anakin Skywalker     188    84.0           Human
# 14        Raymus Antilles     188    79.0           Human
# 15             Mace Windu     188    84.0           Human
# 16               Plo Koon     188    80.0         Kel Dor
# 17            Nute Gunray     191    90.0       Neimodian
# 18                  Dooku     193    80.0           Human
# 19              Kit Fisto     196    87.0        Nautolan
# 20           Ki-Adi-Mundi     198    82.0          Cerean
# 21            Darth Vader     202   136.0           Human
# 22             Tion Medon     206    80.0          Pau'an
# 23               Grievous     216   159.0         Kaleesh
# 24              Chewbacca     228   112.0          Wookie
# 25                Tarfful     234   136.0          Wookie
# 26           Ratts Tyerel      79    15.0          Aleena
# 27               Dud Bolt      94    45.0      Vulptereen
# 28                Sebulba     112    40.0             Dug
# 29         Ben Quadinaros     163    65.0           Toong
# 30             Darth Maul     175    80.0          Zabrak
# 31         Jabba The Hutt     175  1358.0            Hutt
# 32           Qui-Gon Jinn     193    89.0           Human
# 33           Roos Tarpals     224    82.0          Gungan
# 34  Wicket Systri Warrick      88    20.0            Ewok
# 35              Nien Nunb     160    68.0       Sullustan
# 36         Wedge Antilles     170    77.0           Human
# 37       Lando Calrissian     177    79.0           Human
# 38               Han Solo     180    80.0           Human
# 39                 Ackbar     180    83.0    Mon Calamari
# 40          Barriss Offee     166    50.0        Mirialan
# 41             Zam Wesell     168    55.0        Clawdite
# 42              Boba Fett     183    78.2           Human
# 43             Jango Fett     183    79.0           Human
# 44           Gregar Typho     185    85.0           Human
# 45          Jar Jar Binks     196    66.0          Gungan
# 46        Dexter Jettster     198   102.0        Besalisk
# 47                Lama Su     229    88.0        Kaminoan
# 48                 Greedo     173    74.0          Rodian
# 49       Jek Tono Porkins     180   110.0           Human
# 50      Biggs Darklighter     183    84.0           Human
# 51                  Bossk     190   113.0      Trandoshan
#
#     Average Species Height  Number of Film Appearances  \
# 0                       66                           5
# 1                      180                           4
# 2                      180                           3
# 3                      180                           2
# 4                      180                           5
# 5                      180                           4
# 6                      180                           3
# 7                      200                           3
# 8                      180                           2
# 9                      180                           2
# 10                     180                           6
# 11                     178                           2
# 12                     180                           3
# 13                     180                           3
# 14                     180                           2
# 15                     180                           3
# 16                     180                           3
# 17                     180                           3
# 18                     180                           2
# 19                     180                           3
# 20                     200                           3
# 21                     180                           4
# 22                     190                           1
# 23                     170                           1
# 24                     210                           4
# 25                     210                           1
# 26                      80                           1
# 27                     100                           1
# 28                     100                           1
# 29                     200                           1
# 30                     180                           1
# 31                     300                           3
# 32                     180                           1
# 33                     190                           1
# 34                     100                           1
# 35                     180                           1
# 36                     180                           3
# 37                     180                           2
# 38                     180                           3
# 39                     160                           1
# 40                     180                           1
# 41                     180                           1
# 42                     180                           3
# 43                     180                           1
# 44                     180                           1
# 45                     190                           2
# 46                     178                           1
# 47                     220                           1
# 48                     170                           1
# 49                     180                           1
# 50                     180                           1
# 51                     200                           1
#
#       First Film Appearance  Number of Characters_x  Number of Species_x  \
# 0   The Empire Strikes Back                      16                    5
# 1                A New Hope                      18                    5
# 2                A New Hope                      18                    5
# 3      Attack of the Clones                      40                   14
# 4   The Empire Strikes Back                      16                    5
# 5                A New Hope                      18                    5
# 6                A New Hope                      18                    5
# 7        The Phantom Menace                      34                   20
# 8      Attack of the Clones                      40                   14
# 9      Attack of the Clones                      40                   14
# 10               A New Hope                      18                    5
# 11     Attack of the Clones                      40                   14
# 12       The Phantom Menace                      34                   20
# 13       The Phantom Menace                      34                   20
# 14               A New Hope                      18                    5
# 15       The Phantom Menace                      34                   20
# 16       The Phantom Menace                      34                   20
# 17       The Phantom Menace                      34                   20
# 18     Attack of the Clones                      40                   14
# 19       The Phantom Menace                      34                   20
# 20       The Phantom Menace                      34                   20
# 21               A New Hope                      18                    5
# 22      Revenge of the Sith                      34                   20
# 23      Revenge of the Sith                      34                   20
# 24               A New Hope                      18                    5
# 25      Revenge of the Sith                      34                   20
# 26       The Phantom Menace                      34                   20
# 27       The Phantom Menace                      34                   20
# 28       The Phantom Menace                      34                   20
# 29       The Phantom Menace                      34                   20
# 30       The Phantom Menace                      34                   20
# 31               A New Hope                      18                    5
# 32       The Phantom Menace                      34                   20
# 33       The Phantom Menace                      34                   20
# 34       Return of the Jedi                      20                    9
# 35       Return of the Jedi                      20                    9
# 36               A New Hope                      18                    5
# 37  The Empire Strikes Back                      16                    5
# 38               A New Hope                      18                    5
# 39       Return of the Jedi                      20                    9
# 40     Attack of the Clones                      40                   14
# 41     Attack of the Clones                      40                   14
# 42  The Empire Strikes Back                      16                    5
# 43     Attack of the Clones                      40                   14
# 44     Attack of the Clones                      40                   14
# 45       The Phantom Menace                      34                   20
# 46     Attack of the Clones                      40                   14
# 47     Attack of the Clones                      40                   14
# 48               A New Hope                      18                    5
# 49               A New Hope                      18                    5
# 50               A New Hope                      18                    5
# 51  The Empire Strikes Back                      16                    5
#
#     Number of Planets_x  Number of Vehicles_x  Number of Starships_x  \
# 0                     4                     6                      9
# 1                     3                     4                      8
# 2                     3                     4                      8
# 3                     5                    11                      9
# 4                     4                     6                      9
# 5                     3                     4                      8
# 6                     3                     4                      8
# 7                     3                     7                      5
# 8                     5                    11                      9
# 9                     5                    11                      9
# 10                    3                     4                      8
# 11                    5                    11                      9
# 12                    3                     7                      5
# 13                    3                     7                      5
# 14                    3                     4                      8
# 15                    3                     7                      5
# 16                    3                     7                      5
# 17                    3                     7                      5
# 18                    5                    11                      9
# 19                    3                     7                      5
# 20                    3                     7                      5
# 21                    3                     4                      8
# 22                   13                    13                     12
# 23                   13                    13                     12
# 24                    3                     4                      8
# 25                   13                    13                     12
# 26                    3                     7                      5
# 27                    3                     7                      5
# 28                    3                     7                      5
# 29                    3                     7                      5
# 30                    3                     7                      5
# 31                    3                     4                      8
# 32                    3                     7                      5
# 33                    3                     7                      5
# 34                    5                     8                     12
# 35                    5                     8                     12
# 36                    3                     4                      8
# 37                    4                     6                      9
# 38                    3                     4                      8
# 39                    5                     8                     12
# 40                    5                    11                      9
# 41                    5                    11                      9
# 42                    4                     6                      9
# 43                    5                    11                      9
# 44                    5                    11                      9
# 45                    3                     7                      5
# 46                    5                    11                      9
# 47                    5                    11                      9
# 48                    3                     4                      8
# 49                    3                     4                      8
# 50                    3                     4                      8
# 51                    4                     6                      9
#
#        Last Film Appearance  Number of Characters_y  Number of Species_y  \
# 0       Revenge of the Sith                      34                   20
# 1       Revenge of the Sith                      34                   20
# 2       Revenge of the Sith                      34                   20
# 3       Revenge of the Sith                      34                   20
# 4       Revenge of the Sith                      34                   20
# 5       Revenge of the Sith                      34                   20
# 6       Revenge of the Sith                      34                   20
# 7       Revenge of the Sith                      34                   20
# 8       Revenge of the Sith                      34                   20
# 9       Revenge of the Sith                      34                   20
# 10      Revenge of the Sith                      34                   20
# 11      Revenge of the Sith                      34                   20
# 12      Revenge of the Sith                      34                   20
# 13      Revenge of the Sith                      34                   20
# 14      Revenge of the Sith                      34                   20
# 15      Revenge of the Sith                      34                   20
# 16      Revenge of the Sith                      34                   20
# 17      Revenge of the Sith                      34                   20
# 18      Revenge of the Sith                      34                   20
# 19      Revenge of the Sith                      34                   20
# 20      Revenge of the Sith                      34                   20
# 21      Revenge of the Sith                      34                   20
# 22      Revenge of the Sith                      34                   20
# 23      Revenge of the Sith                      34                   20
# 24      Revenge of the Sith                      34                   20
# 25      Revenge of the Sith                      34                   20
# 26       The Phantom Menace                      34                   20
# 27       The Phantom Menace                      34                   20
# 28       The Phantom Menace                      34                   20
# 29       The Phantom Menace                      34                   20
# 30       The Phantom Menace                      34                   20
# 31       The Phantom Menace                      34                   20
# 32       The Phantom Menace                      34                   20
# 33       The Phantom Menace                      34                   20
# 34       Return of the Jedi                      20                    9
# 35       Return of the Jedi                      20                    9
# 36       Return of the Jedi                      20                    9
# 37       Return of the Jedi                      20                    9
# 38       Return of the Jedi                      20                    9
# 39       Return of the Jedi                      20                    9
# 40     Attack of the Clones                      40                   14
# 41     Attack of the Clones                      40                   14
# 42     Attack of the Clones                      40                   14
# 43     Attack of the Clones                      40                   14
# 44     Attack of the Clones                      40                   14
# 45     Attack of the Clones                      40                   14
# 46     Attack of the Clones                      40                   14
# 47     Attack of the Clones                      40                   14
# 48               A New Hope                      18                    5
# 49               A New Hope                      18                    5
# 50               A New Hope                      18                    5
# 51  The Empire Strikes Back                      16                    5
#
#     Number of Planets_y  Number of Vehicles_y  Number of Starships_y
# 0                    13                    13                     12
# 1                    13                    13                     12
# 2                    13                    13                     12
# 3                    13                    13                     12
# 4                    13                    13                     12
# 5                    13                    13                     12
# 6                    13                    13                     12
# 7                    13                    13                     12
# 8                    13                    13                     12
# 9                    13                    13                     12
# 10                   13                    13                     12
# 11                   13                    13                     12
# 12                   13                    13                     12
# 13                   13                    13                     12
# 14                   13                    13                     12
# 15                   13                    13                     12
# 16                   13                    13                     12
# 17                   13                    13                     12
# 18                   13                    13                     12
# 19                   13                    13                     12
# 20                   13                    13                     12
# 21                   13                    13                     12
# 22                   13                    13                     12
# 23                   13                    13                     12
# 24                   13                    13                     12
# 25                   13                    13                     12
# 26                    3                     7                      5
# 27                    3                     7                      5
# 28                    3                     7                      5
# 29                    3                     7                      5
# 30                    3                     7                      5
# 31                    3                     7                      5
# 32                    3                     7                      5
# 33                    3                     7                      5
# 34                    5                     8                     12
# 35                    5                     8                     12
# 36                    5                     8                     12
# 37                    5                     8                     12
# 38                    5                     8                     12
# 39                    5                     8                     12
# 40                    5                    11                      9
# 41                    5                    11                      9
# 42                    5                    11                      9
# 43                    5                    11                      9
# 44                    5                    11                      9
# 45                    5                    11                      9
# 46                    5                    11                      9
# 47                    5                    11                      9
# 48                    3                     4                      8
# 49                    3                     4                      8
# 50                    3                     4                      8
# 51                    4                     6                      9

# %%
# Height and Mass Dataframes by descending order for ease of plotting

height_df = clean_characters_df.sort_values("Height", ascending=False)
print(height_df.head())

mass_df = clean_characters_df.sort_values("Mass", ascending=False)
print(mass_df.head())
# Out:
#        Character  Height   Mass                               URL  \
# 55       Tarfful     234  136.0   http://swapi.dev/api/species/3/
# 51       Lama Su     229   88.0  http://swapi.dev/api/species/32/
# 11     Chewbacca     228  112.0   http://swapi.dev/api/species/3/
# 31  Roos Tarpals     224   82.0  http://swapi.dev/api/species/12/
# 54      Grievous     216  159.0  http://swapi.dev/api/species/36/
#
#                        First Film                      Last Film  \
# 55  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
# 51  http://swapi.dev/api/films/5/  http://swapi.dev/api/films/5/
# 11  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 31  http://swapi.dev/api/films/4/  http://swapi.dev/api/films/4/
# 54  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
#
#     Number of Film Appearances
# 55                           1
# 51                           1
# 11                           4
# 31                           1
# 54                           1
#          Character  Height    Mass                               URL  \
# 14  Jabba The Hutt     175  1358.0   http://swapi.dev/api/species/5/
# 54        Grievous     216   159.0  http://swapi.dev/api/species/36/
# 20           IG-88     200   140.0   http://swapi.dev/api/species/2/
# 3      Darth Vader     202   136.0   http://swapi.dev/api/species/1/
# 55         Tarfful     234   136.0   http://swapi.dev/api/species/3/
#
#                        First Film                      Last Film  \
# 14  http://swapi.dev/api/films/1/  http://swapi.dev/api/films/4/
# 54  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
# 20  http://swapi.dev/api/films/2/  http://swapi.dev/api/films/2/
# 3   http://swapi.dev/api/films/1/  http://swapi.dev/api/films/6/
# 55  http://swapi.dev/api/films/6/  http://swapi.dev/api/films/6/
#
#     Number of Film Appearances
# 14                           3
# 54                           1
# 20                           1
# 3                            4
# 55                           1

# %%
#bar chart for character heights
tick_locations = [value for value in clean_characters_df["Character"]]
labels = clean_characters_df["Character"]
plt.figure(figsize=(20, 15))
plt.bar(height_df["Character"], height_df["Height"])
plt.xticks(tick_locations, labels, rotation="vertical")
plt.ylabel("Height (cm)")
plt.xlabel("Characters")
plt.title("Star Wars Character Heights")
plt.savefig("Figures/Bar_Character_Height.png")
plt.show()

print(clean_characters_df.describe())
# Out:
#            Height         Mass  Number of Film Appearances
# count   59.000000    59.000000                   59.000000
# mean   174.355932    97.311864                    2.220339
# std     35.536656   169.457163                    1.439202
# min     66.000000    15.000000                    1.000000
# 25%    170.000000    55.600000                    1.000000
# 50%    180.000000    79.000000                    2.000000
# 75%    192.000000    84.500000                    3.000000
# max    234.000000  1358.000000                    6.000000

# %%
#bar chart for character masses
tick_locations = [value for value in clean_characters_df["Character"]]
labels = clean_characters_df["Character"]
plt.figure(figsize=(20, 15))
plt.bar(mass_df["Character"], mass_df["Mass"])
plt.xticks(tick_locations, labels, rotation="vertical")
plt.title("Star Wars Character Masses")
plt.savefig("Figures/Bar_Character_Mass.png")
plt.show()

# %%
#Remove Jabba from the Index and plot again to show the mass distribution
no_jabba_mass_df = clean_characters_df.drop([14])
no_jabba_mass_df = no_jabba_mass_df.sort_values(["Mass"], ascending=False)
no_jabba_mass_df = no_jabba_mass_df.reset_index(drop=True)

tick_locations = [value for value in no_jabba_mass_df["Character"]]
labels = no_jabba_mass_df["Character"]
plt.figure(figsize=(20, 15))
plt.bar(no_jabba_mass_df["Character"], no_jabba_mass_df["Mass"])
plt.xticks(tick_locations, labels, rotation="vertical")
plt.title("Star Wars Character Masses (Minus Jabba)")
plt.savefig("Figures/Bar_Character_Mass_NoJabba.png")
plt.show()

# %%
#scatter plot height vs mass with Jabba
x_values = clean_characters_df["Height"]
y_values = clean_characters_df["Mass"].astype(float)
plt.figure(figsize=(20,15))
plt.scatter(x_values, y_values, edgecolors="black")
#regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(130,100),fontsize=12,color="red")
#aesthetics
plt.grid()
plt.title("Character Height vs Mass")
plt.xlabel("Character Height (cm)")
plt.ylabel("Character Mass (kg)")
plt.savefig("Figures/Scatter_Character_HeightVsMass.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.017124071816855775

# %%
#scatter plot height vs mass wihout Jabba
x_values = no_jabba_mass_df["Height"]
y_values = no_jabba_mass_df["Mass"]
plt.figure(figsize=(20,15))
plt.scatter(x_values, y_values, edgecolors="black")
#regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
r_squared = rvalue**2
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(130,60),fontsize=12,color="red")
#aesthetics
plt.grid()
plt.title("Character Height vs Mass with No Jabba")
plt.xlabel("Character Height (cm)")
plt.ylabel("Character Mass (kg)")
plt.savefig("Figures/Scatter_Character_HeightVsMass_NoJabba.png")
plt.show()
print(f"The r-squared is: {r_squared}")
# Out:
# The r-squared is: 0.5637880133716309

# %%
plot_mass_df = mass_df.drop(columns=["Height", "URL", "First Film", "Last Film", "Number of Film Appearances"])
plot_mass_df
# Out:
#                 Character    Mass
# 14         Jabba The Hutt  1358.0
# 54               Grievous   159.0
# 20                  IG-88   140.0
# 3             Darth Vader   136.0
# 55                Tarfful   136.0
# 5               Owen Lars   120.0
# 21                  Bossk   113.0
# 11              Chewbacca   112.0
# 16       Jek Tono Porkins   110.0
# 50        Dexter Jettster   102.0
# 28            Nute Gunray    90.0
# 27           Qui-Gon Jinn    89.0
# 51                Lama Su    88.0
# 40              Kit Fisto    87.0
# 43           Gregar Typho    85.0
# 8       Biggs Darklighter    84.0
# 38             Mace Windu    84.0
# 10       Anakin Skywalker    84.0
# 24                 Ackbar    83.0
# 39           Ki-Adi-Mundi    82.0
# 31           Roos Tarpals    82.0
# 44      Poggle the Lesser    80.0
# 42               Plo Koon    80.0
# 33             Darth Maul    80.0
# 47                  Dooku    80.0
# 12               Han Solo    80.0
# 58             Tion Medon    80.0
# 22       Lando Calrissian    79.0
# 23                  Lobot    79.0
# 48             Jango Fett    79.0
# 56        Raymus Antilles    79.0
# 19              Boba Fett    78.2
# 0          Luke Skywalker    77.0
# 9          Obi-Wan Kenobi    77.0
# 15         Wedge Antilles    77.0
# 1                   C-3PO    75.0
# 18              Palpatine    75.0
# 6      Beru Whitesun lars    75.0
# 13                 Greedo    74.0
# 26              Nien Nunb    68.0
# 30          Jar Jar Binks    66.0
# 37         Ben Quadinaros    65.0
# 53               Shaak Ti    57.0
# 45        Luminara Unduli    56.2
# 34            Ayla Secura    55.0
# 49             Zam Wesell    55.0
# 41             Adi Gallia    50.0
# 46          Barriss Offee    50.0
# 4             Leia Organa    49.0
# 52             Wat Tambor    48.0
# 57              Sly Moore    48.0
# 29          Padmé Amidala    45.0
# 36               Dud Bolt    45.0
# 32                Sebulba    40.0
# 7                   R5-D4    32.0
# 2                   R2-D2    32.0
# 25  Wicket Systri Warrick    20.0
# 17                   Yoda    17.0
# 35           Ratts Tyerel    15.0

# %%
# separate Characters into Jabba and Everyone else
jabba_mass_df = plot_mass_df[0:1]
other_characters_mass_df = plot_mass_df[1 : 59]

#Find the sum of the masses of characters in each category and save the figures
jabba_mass = jabba_mass_df["Mass"].sum()
other_characters_mass = other_characters_mass_df["Mass"].sum()
print(f'Jabba Mass: {jabba_mass} kg')
print(f'All Other Character Masses: {other_characters_mass} kg')
# Out:
# Jabba Mass: 1358.0 kg
# All Other Character Masses: 4383.4 kg

# %%
#Pie Chart for Jabba The Hutt vs All Other Characters
labels = ["Jabba The Hutt Mass", "All Other Characters Combined Masses"]
ship_size_list = [jabba_mass, other_characters_mass]
colors = ["orange", "green"]
explode = (0.1, 0)
plt.pie(ship_size_list, explode = explode, labels = labels, colors = colors, autopct = "%1.1f%%", shadow = True, startangle = 69)
plt.title("Jabba The Hutt vs All Other Characters Masses")
plt.savefig("Figures/Pie_Jabba_Mass_Vs.png")
plt.show()

# %%
#Statistical breakdown of character masses with Jabba
plt.hist(mass_df["Mass"])
plt.title("Star Wars Character Mass Distribution")
plt.xlabel("Character Mass (kg)")
plt.ylabel("Counts")
plt.savefig("Figures/Hist_Character_Mass.png")
plt.show()
print(sts.normaltest(mass_df["Mass"].sample(50)))
print('------------------------------------------')
#stdev and var using numpy
sd_numpy = np.std(mass_df["Mass"],ddof = 0)
print(f"The sample standard deviation is {round(sd_numpy,1)}")
var_numpy = np.var(mass_df["Mass"],ddof = 0)
print(f"The sample variance using the NumPy module is {round(var_numpy,1)}")
print('------------------------------------------')
# Calculate the 68-95-99.7 rule using the standard deviation
mean_numpy = np.mean(mass_df["Mass"])
print(f"The mean mass of Star Wars characters with Jabba is {round(mean_numpy,1)}")
print('------------------------------------------')
print(f"Roughly 68% of the data is between {round(mean_numpy-sd_numpy,1)} and {round(mean_numpy+sd_numpy,1)} kgs")
print(f"Roughly 95% of the data is between {round(mean_numpy-2*sd_numpy,1)} and {round(mean_numpy+2*sd_numpy,1)} kgs")
print(f"Roughly 99.7% of the data is between {round(mean_numpy-3*sd_numpy,1)} and {round(mean_numpy+3*sd_numpy,1)} kgs")
# Out:
# NormaltestResult(statistic=109.33516212394784, pvalue=1.812054292432805e-24)
# ------------------------------------------
# The sample standard deviation is 168.0
# The sample variance using the NumPy module is 28229.0
# ------------------------------------------
# The mean mass of Star Wars characters with Jabba is 97.3
# ------------------------------------------
# Roughly 68% of the data is between -70.7 and 265.3 kgs
# Roughly 95% of the data is between -238.7 and 433.3 kgs
# Roughly 99.7% of the data is between -406.7 and 601.4 kgs

# %%
##Statistical breakdown of character masses without Jabba
plt.hist(no_jabba_mass_df["Mass"])
plt.title("Star Wars Character Mass Distribution without Jabba")
plt.xlabel("Character Mass (kg)")
plt.ylabel("Counts")
plt.savefig("Figures/Hist_Character_Mass_NoJabba.png")
plt.show()
print(sts.normaltest(no_jabba_mass_df["Mass"].sample(50)))
print('------------------------------------------')
#stdev and var using numpy
sd_numpy = np.std(no_jabba_mass_df["Mass"],ddof = 0)
print(f"The sample standard deviation is {round(sd_numpy,1)}")
var_numpy = np.var(no_jabba_mass_df["Mass"],ddof = 0)
print(f"The sample variance using the NumPy module is {round(var_numpy,1)}")
print('------------------------------------------')
# Calculate the 68-95-99.7 rule using the standard deviation
mean_numpy = np.mean(no_jabba_mass_df["Mass"])
print(f"The mean mass of Star Wars characters without Jabba is {round(mean_numpy,1)}")
print('------------------------------------------')
print(f"Roughly 68% of the data is between {round(mean_numpy-sd_numpy,1)} and {round(mean_numpy+sd_numpy,1)} kgs")
print(f"Roughly 95% of the data is between {round(mean_numpy-2*sd_numpy,1)} and {round(mean_numpy+2*sd_numpy,1)} kgs")
print(f"Roughly 99.7% of the data is between {round(mean_numpy-3*sd_numpy,1)} and {round(mean_numpy+3*sd_numpy,1)} kgs")
# Out:
# NormaltestResult(statistic=4.664124539898232, pvalue=0.09709530374931151)
# ------------------------------------------
# The sample standard deviation is 29.0
# The sample variance using the NumPy module is 841.0
# ------------------------------------------
# The mean mass of Star Wars characters without Jabba is 75.6
# ------------------------------------------
# Roughly 68% of the data is between 46.6 and 104.6 kgs
# Roughly 95% of the data is between 17.6 and 133.6 kgs
# Roughly 99.7% of the data is between -11.4 and 162.6 kgs

# %%
#Statistics Summary
print(f'Statistical Analysis of Mass with Jabba:')
print(mass_df["Mass"].describe())
print(f'Statistical Analysis of Mass without Jabba:')
print(no_jabba_mass_df["Mass"].describe())
# Out:
# Statistical Analysis of Mass with Jabba:
# count      59.000000
# mean       97.311864
# std       169.457163
# min        15.000000
# 25%        55.600000
# 50%        79.000000
# 75%        84.500000
# max      1358.000000
# Name: Mass, dtype: float64
# Statistical Analysis of Mass without Jabba:
# count     58.000000
# mean      75.575862
# std       29.252514
# min       15.000000
# 25%       55.300000
# 50%       79.000000
# 75%       84.000000
# max      159.000000
# Name: Mass, dtype: float64

# %% [markdown]
# # Star Wars Starships

# %%
#starships
url_starships = "http://swapi.dev/api/starships/"
starships_response = requests.get(url_starships).json()
print(json.dumps(starships_response, indent=2, sort_keys=True))
# Out:
# {
#   "count": 36,
#   "next": "http://swapi.dev/api/starships/?page=2",
#   "previous": null,
#   "results": [
#     {
#       "MGLT": "60",
#       "cargo_capacity": "3000000",
#       "consumables": "1 year",
#       "cost_in_credits": "3500000",
#       "created": "2014-12-10T14:20:33.369000Z",
#       "crew": "30-165",
#       "edited": "2014-12-20T21:23:49.867000Z",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/3/",
#         "http://swapi.dev/api/films/6/"
#       ],
#       "hyperdrive_rating": "2.0",
#       "length": "150",
#       "manufacturer": "Corellian Engineering Corporation",
#       "max_atmosphering_speed": "950",
#       "model": "CR90 corvette",
#       "name": "CR90 corvette",
#       "passengers": "600",
#       "pilots": [],
#       "starship_class": "corvette",
#       "url": "http://swapi.dev/api/starships/2/"
#     },
#     {
#       "MGLT": "60",
#       "cargo_capacity": "36000000",
#       "consumables": "2 years",
#       "cost_in_credits": "150000000",
#       "created": "2014-12-10T15:08:19.848000Z",
#       "crew": "47,060",
#       "edited": "2014-12-20T21:23:49.870000Z",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/"
#       ],
#       "hyperdrive_rating": "2.0",
#       "length": "1,600",
#       "manufacturer": "Kuat Drive Yards",
#       "max_atmosphering_speed": "975",
#       "model": "Imperial I-class Star Destroyer",
#       "name": "Star Destroyer",
#       "passengers": "n/a",
#       "pilots": [],
#       "starship_class": "Star Destroyer",
#       "url": "http://swapi.dev/api/starships/3/"
#     },
#     {
#       "MGLT": "70",
#       "cargo_capacity": "180000",
#       "consumables": "1 month",
#       "cost_in_credits": "240000",
#       "created": "2014-12-10T15:48:00.586000Z",
#       "crew": "5",
#       "edited": "2014-12-20T21:23:49.873000Z",
#       "films": [
#         "http://swapi.dev/api/films/1/"
#       ],
#       "hyperdrive_rating": "1.0",
#       "length": "38",
#       "manufacturer": "Sienar Fleet Systems, Cyngus Spaceworks",
#       "max_atmosphering_speed": "1000",
#       "model": "Sentinel-class landing craft",
#       "name": "Sentinel-class landing craft",
#       "passengers": "75",
#       "pilots": [],
#       "starship_class": "landing craft",
#       "url": "http://swapi.dev/api/starships/5/"
#     },
#     {
#       "MGLT": "10",
#       "cargo_capacity": "1000000000000",
#       "consumables": "3 years",
#       "cost_in_credits": "1000000000000",
#       "created": "2014-12-10T16:36:50.509000Z",
#       "crew": "342,953",
#       "edited": "2014-12-20T21:26:24.783000Z",
#       "films": [
#         "http://swapi.dev/api/films/1/"
#       ],
#       "hyperdrive_rating": "4.0",
#       "length": "120000",
#       "manufacturer": "Imperial Department of Military Research, Sienar Fleet Systems",
#       "max_atmosphering_speed": "n/a",
#       "model": "DS-1 Orbital Battle Station",
#       "name": "Death Star",
#       "passengers": "843,342",
#       "pilots": [],
#       "starship_class": "Deep Space Mobile Battlestation",
#       "url": "http://swapi.dev/api/starships/9/"
#     },
#     {
#       "MGLT": "75",
#       "cargo_capacity": "100000",
#       "consumables": "2 months",
#       "cost_in_credits": "100000",
#       "created": "2014-12-10T16:59:45.094000Z",
#       "crew": "4",
#       "edited": "2014-12-20T21:23:49.880000Z",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/"
#       ],
#       "hyperdrive_rating": "0.5",
#       "length": "34.37",
#       "manufacturer": "Corellian Engineering Corporation",
#       "max_atmosphering_speed": "1050",
#       "model": "YT-1300 light freighter",
#       "name": "Millennium Falcon",
#       "passengers": "6",
#       "pilots": [
#         "http://swapi.dev/api/people/13/",
#         "http://swapi.dev/api/people/14/",
#         "http://swapi.dev/api/people/25/",
#         "http://swapi.dev/api/people/31/"
#       ],
#       "starship_class": "Light freighter",
#       "url": "http://swapi.dev/api/starships/10/"
#     },
#     {
#       "MGLT": "80",
#       "cargo_capacity": "110",
#       "consumables": "1 week",
#       "cost_in_credits": "134999",
#       "created": "2014-12-12T11:00:39.817000Z",
#       "crew": "2",
#       "edited": "2014-12-20T21:23:49.883000Z",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/"
#       ],
#       "hyperdrive_rating": "1.0",
#       "length": "14",
#       "manufacturer": "Koensayr Manufacturing",
#       "max_atmosphering_speed": "1000km",
#       "model": "BTL Y-wing",
#       "name": "Y-wing",
#       "passengers": "0",
#       "pilots": [],
#       "starship_class": "assault starfighter",
#       "url": "http://swapi.dev/api/starships/11/"
#     },
#     {
#       "MGLT": "100",
#       "cargo_capacity": "110",
#       "consumables": "1 week",
#       "cost_in_credits": "149999",
#       "created": "2014-12-12T11:19:05.340000Z",
#       "crew": "1",
#       "edited": "2014-12-20T21:23:49.886000Z",
#       "films": [
#         "http://swapi.dev/api/films/1/",
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/"
#       ],
#       "hyperdrive_rating": "1.0",
#       "length": "12.5",
#       "manufacturer": "Incom Corporation",
#       "max_atmosphering_speed": "1050",
#       "model": "T-65 X-wing",
#       "name": "X-wing",
#       "passengers": "0",
#       "pilots": [
#         "http://swapi.dev/api/people/1/",
#         "http://swapi.dev/api/people/9/",
#         "http://swapi.dev/api/people/18/",
#         "http://swapi.dev/api/people/19/"
#       ],
#       "starship_class": "Starfighter",
#       "url": "http://swapi.dev/api/starships/12/"
#     },
#     {
#       "MGLT": "105",
#       "cargo_capacity": "150",
#       "consumables": "5 days",
#       "cost_in_credits": "unknown",
#       "created": "2014-12-12T11:21:32.991000Z",
#       "crew": "1",
#       "edited": "2014-12-20T21:23:49.889000Z",
#       "films": [
#         "http://swapi.dev/api/films/1/"
#       ],
#       "hyperdrive_rating": "1.0",
#       "length": "9.2",
#       "manufacturer": "Sienar Fleet Systems",
#       "max_atmosphering_speed": "1200",
#       "model": "Twin Ion Engine Advanced x1",
#       "name": "TIE Advanced x1",
#       "passengers": "0",
#       "pilots": [
#         "http://swapi.dev/api/people/4/"
#       ],
#       "starship_class": "Starfighter",
#       "url": "http://swapi.dev/api/starships/13/"
#     },
#     {
#       "MGLT": "40",
#       "cargo_capacity": "250000000",
#       "consumables": "6 years",
#       "cost_in_credits": "1143350000",
#       "created": "2014-12-15T12:31:42.547000Z",
#       "crew": "279,144",
#       "edited": "2014-12-20T21:23:49.893000Z",
#       "films": [
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/"
#       ],
#       "hyperdrive_rating": "2.0",
#       "length": "19000",
#       "manufacturer": "Kuat Drive Yards, Fondor Shipyards",
#       "max_atmosphering_speed": "n/a",
#       "model": "Executor-class star dreadnought",
#       "name": "Executor",
#       "passengers": "38000",
#       "pilots": [],
#       "starship_class": "Star dreadnought",
#       "url": "http://swapi.dev/api/starships/15/"
#     },
#     {
#       "MGLT": "20",
#       "cargo_capacity": "19000000",
#       "consumables": "6 months",
#       "cost_in_credits": "unknown",
#       "created": "2014-12-15T12:34:52.264000Z",
#       "crew": "6",
#       "edited": "2014-12-20T21:23:49.895000Z",
#       "films": [
#         "http://swapi.dev/api/films/2/",
#         "http://swapi.dev/api/films/3/"
#       ],
#       "hyperdrive_rating": "4.0",
#       "length": "90",
#       "manufacturer": "Gallofree Yards, Inc.",
#       "max_atmosphering_speed": "650",
#       "model": "GR-75 medium transport",
#       "name": "Rebel transport",
#       "passengers": "90",
#       "pilots": [],
#       "starship_class": "Medium transport",
#       "url": "http://swapi.dev/api/starships/17/"
#     }
#   ]
# }

# %%
#new lists to store Starship info
starship_names = []
starship_models = []
starship_class = []
starship_length = []
starship_crew = []
starship_films = []
starship_consumables = []
starship_cost = []
page = ["1", "2", "3", "4"]
find_starship_url = f"http://swapi.dev/api/starships/?page="

for x in page:
    find_ships_response = requests.get(find_starship_url + x).json()
    
#for loop to list names in films
    for ships in find_ships_response["results"]:
        ship_name = ships["name"]
        starship_names.append(ship_name)
        ship_model = ships["model"]
        starship_models.append(ship_model)
        ship_class = ships["starship_class"]
        starship_class.append(ship_class)
        ship_length = ships["length"]
        starship_length.append(ship_length)
        ship_crew = ships["crew"]
        starship_crew.append(ship_crew)
        ship_films = ships["films"]
        starship_films.append(ship_films)
        ship_consumables = ships["consumables"]
        starship_consumables.append(ship_consumables)
        ship_cost = ships["cost_in_credits"]
        starship_cost.append(ship_cost)
        print(f'{ship_name} found!')
# Out:
# CR90 corvette found!
# Star Destroyer found!
# Sentinel-class landing craft found!
# Death Star found!
# Millennium Falcon found!
# Y-wing found!
# X-wing found!
# TIE Advanced x1 found!
# Executor found!
# Rebel transport found!
# Slave 1 found!
# Imperial shuttle found!
# EF76 Nebulon-B escort frigate found!
# Calamari Cruiser found!
# A-wing found!
# B-wing found!
# Republic Cruiser found!
# Droid control ship found!
# Naboo fighter found!
# Naboo Royal Starship found!
# Scimitar found!
# J-type diplomatic barge found!
# AA-9 Coruscant freighter found!
# Jedi starfighter found!
# H-type Nubian yacht found!
# Republic Assault ship found!
# Solar Sailer found!
# Trade Federation cruiser found!
# Theta-class T-2c shuttle found!
# Republic attack cruiser found!
# Naboo star skiff found!
# Jedi Interceptor found!
# arc-170 found!
# Banking clan frigte found!
# Belbullab-22 starfighter found!
# V-wing found!

# %%
starship_df = pd.DataFrame({"Name": starship_names, 
                            "Length (meters)": starship_length,
                            "Model": starship_models,
                            "Class": starship_class,
                            "Cost (credits)": starship_cost,
                            "Consumables": starship_consumables,
                            "Crew": starship_crew,
                            "Films": starship_films
                            })
starship_df
# Out:
#                              Name Length (meters)  \
# 0                   CR90 corvette             150
# 1                  Star Destroyer           1,600
# 2    Sentinel-class landing craft              38
# 3                      Death Star          120000
# 4               Millennium Falcon           34.37
# 5                          Y-wing              14
# 6                          X-wing            12.5
# 7                 TIE Advanced x1             9.2
# 8                        Executor           19000
# 9                 Rebel transport              90
# 10                        Slave 1            21.5
# 11               Imperial shuttle              20
# 12  EF76 Nebulon-B escort frigate             300
# 13               Calamari Cruiser            1200
# 14                         A-wing             9.6
# 15                         B-wing            16.9
# 16               Republic Cruiser             115
# 17             Droid control ship            3170
# 18                  Naboo fighter              11
# 19           Naboo Royal Starship              76
# 20                       Scimitar            26.5
# 21        J-type diplomatic barge              39
# 22       AA-9 Coruscant freighter             390
# 23               Jedi starfighter               8
# 24            H-type Nubian yacht            47.9
# 25          Republic Assault ship             752
# 26                   Solar Sailer            15.2
# 27       Trade Federation cruiser            1088
# 28       Theta-class T-2c shuttle            18.5
# 29        Republic attack cruiser            1137
# 30               Naboo star skiff            29.2
# 31               Jedi Interceptor            5.47
# 32                        arc-170            14.5
# 33            Banking clan frigte             825
# 34       Belbullab-22 starfighter            6.71
# 35                         V-wing             7.9
#
#                                        Model                            Class  \
# 0                              CR90 corvette                         corvette
# 1            Imperial I-class Star Destroyer                   Star Destroyer
# 2               Sentinel-class landing craft                    landing craft
# 3                DS-1 Orbital Battle Station  Deep Space Mobile Battlestation
# 4                    YT-1300 light freighter                  Light freighter
# 5                                 BTL Y-wing              assault starfighter
# 6                                T-65 X-wing                      Starfighter
# 7                Twin Ion Engine Advanced x1                      Starfighter
# 8            Executor-class star dreadnought                 Star dreadnought
# 9                     GR-75 medium transport                 Medium transport
# 10      Firespray-31-class patrol and attack                     Patrol craft
# 11                 Lambda-class T-4a shuttle       Armed government transport
# 12             EF76 Nebulon-B escort frigate                      Escort ship
# 13            MC80 Liberty type Star Cruiser                     Star Cruiser
# 14                   RZ-1 A-wing Interceptor                      Starfighter
# 15                A/SF-01 B-wing starfighter              Assault Starfighter
# 16                    Consular-class cruiser                    Space cruiser
# 17        Lucrehulk-class Droid Control Ship               Droid control ship
# 18                           N-1 starfighter                      Starfighter
# 19          J-type 327 Nubian royal starship                            yacht
# 20                              Star Courier                  Space Transport
# 21                   J-type diplomatic barge                 Diplomatic barge
# 22              Botajef AA-9 Freighter-Liner                        freighter
# 23    Delta-7 Aethersprite-class interceptor                      Starfighter
# 24                       H-type Nubian yacht                            yacht
# 25           Acclamator I-class assault ship                     assault ship
# 26    Punworcca 116-class interstellar sloop                            yacht
# 27        Providence-class carrier/destroyer                     capital ship
# 28                  Theta-class T-2c shuttle                        transport
# 29              Senator-class Star Destroyer                   star destroyer
# 30                         J-type star skiff                            yacht
# 31       Eta-2 Actis-class light interceptor                      starfighter
# 32  Aggressive Reconnaissance-170 starfighte                      starfighter
# 33             Munificent-class star frigate                          cruiser
# 34                  Belbullab-22 starfighter                      starfighter
# 35   Alpha-3 Nimbus-class V-wing starfighter                      starfighter
#
#    Cost (credits) Consumables     Crew  \
# 0         3500000      1 year   30-165
# 1       150000000     2 years   47,060
# 2          240000     1 month        5
# 3   1000000000000     3 years  342,953
# 4          100000    2 months        4
# 5          134999      1 week        2
# 6          149999      1 week        1
# 7         unknown      5 days        1
# 8      1143350000     6 years  279,144
# 9         unknown    6 months        6
# 10        unknown     1 month        1
# 11         240000    2 months        6
# 12        8500000     2 years      854
# 13      104000000     2 years     5400
# 14         175000      1 week        1
# 15         220000      1 week        1
# 16        unknown     unknown        9
# 17        unknown    500 days      175
# 18         200000      7 days        1
# 19        unknown     unknown        8
# 20       55000000     30 days        1
# 21        2000000      1 year        5
# 22        unknown     unknown  unknown
# 23         180000      7 days        1
# 24        unknown     unknown        4
# 25        unknown     2 years      700
# 26          35700      7 days        3
# 27      125000000     4 years      600
# 28        1000000     56 days        5
# 29       59000000     2 years     7400
# 30        unknown     unknown        3
# 31         320000      2 days        1
# 32         155000      5 days        3
# 33       57000000     2 years      200
# 34         168000      7 days        1
# 35         102500    15 hours        1
#
#                                                 Films
# 0   [http://swapi.dev/api/films/1/, http://swapi.d...
# 1   [http://swapi.dev/api/films/1/, http://swapi.d...
# 2                     [http://swapi.dev/api/films/1/]
# 3                     [http://swapi.dev/api/films/1/]
# 4   [http://swapi.dev/api/films/1/, http://swapi.d...
# 5   [http://swapi.dev/api/films/1/, http://swapi.d...
# 6   [http://swapi.dev/api/films/1/, http://swapi.d...
# 7                     [http://swapi.dev/api/films/1/]
# 8   [http://swapi.dev/api/films/2/, http://swapi.d...
# 9   [http://swapi.dev/api/films/2/, http://swapi.d...
# 10  [http://swapi.dev/api/films/2/, http://swapi.d...
# 11  [http://swapi.dev/api/films/2/, http://swapi.d...
# 12  [http://swapi.dev/api/films/2/, http://swapi.d...
# 13                    [http://swapi.dev/api/films/3/]
# 14                    [http://swapi.dev/api/films/3/]
# 15                    [http://swapi.dev/api/films/3/]
# 16                    [http://swapi.dev/api/films/4/]
# 17  [http://swapi.dev/api/films/4/, http://swapi.d...
# 18  [http://swapi.dev/api/films/4/, http://swapi.d...
# 19                    [http://swapi.dev/api/films/4/]
# 20                    [http://swapi.dev/api/films/4/]
# 21                    [http://swapi.dev/api/films/5/]
# 22                    [http://swapi.dev/api/films/5/]
# 23  [http://swapi.dev/api/films/5/, http://swapi.d...
# 24                    [http://swapi.dev/api/films/5/]
# 25                    [http://swapi.dev/api/films/5/]
# 26                    [http://swapi.dev/api/films/5/]
# 27                    [http://swapi.dev/api/films/6/]
# 28                    [http://swapi.dev/api/films/6/]
# 29                    [http://swapi.dev/api/films/6/]
# 30                    [http://swapi.dev/api/films/6/]
# 31                    [http://swapi.dev/api/films/6/]
# 32                    [http://swapi.dev/api/films/6/]
# 33                    [http://swapi.dev/api/films/6/]
# 34                    [http://swapi.dev/api/films/6/]
# 35                    [http://swapi.dev/api/films/6/]

# %%
#clean value "1,600" to "1600" for Star Destroyer Length
starship_df.iloc[[1],[1]] = 1600
#loop to convert all Length values to Floats
for i in range(0, len(starship_df["Length (meters)"])):
    starship_df["Length (meters)"][i]=float(starship_df["Length (meters)"][i])
#sort starships by length
length_starship_df = starship_df.sort_values("Length (meters)", ascending=False)
length_starship_df = length_starship_df.reset_index(drop=True)
length_starship_df = length_starship_df.drop(columns=["Model", "Class", "Cost (credits)", "Consumables", "Crew", "Films"])
length_starship_df
# Out:
#                              Name Length (meters)
# 0                      Death Star          120000
# 1                        Executor           19000
# 2              Droid control ship            3170
# 3                  Star Destroyer            1600
# 4                Calamari Cruiser            1200
# 5         Republic attack cruiser            1137
# 6        Trade Federation cruiser            1088
# 7             Banking clan frigte             825
# 8           Republic Assault ship             752
# 9        AA-9 Coruscant freighter             390
# 10  EF76 Nebulon-B escort frigate             300
# 11                  CR90 corvette             150
# 12               Republic Cruiser             115
# 13                Rebel transport              90
# 14           Naboo Royal Starship              76
# 15            H-type Nubian yacht            47.9
# 16        J-type diplomatic barge              39
# 17   Sentinel-class landing craft              38
# 18              Millennium Falcon           34.37
# 19               Naboo star skiff            29.2
# 20                       Scimitar            26.5
# 21                        Slave 1            21.5
# 22               Imperial shuttle              20
# 23       Theta-class T-2c shuttle            18.5
# 24                         B-wing            16.9
# 25                   Solar Sailer            15.2
# 26                        arc-170            14.5
# 27                         Y-wing              14
# 28                         X-wing            12.5
# 29                  Naboo fighter              11
# 30                         A-wing             9.6
# 31                TIE Advanced x1             9.2
# 32               Jedi starfighter               8
# 33                         V-wing             7.9
# 34       Belbullab-22 starfighter            6.71
# 35               Jedi Interceptor            5.47

# %%
x_axis = length_starship_df["Name"]
y_axis = length_starship_df["Length (meters)"]
tick_locations = [value for value in x_axis]
plt.figure(figsize=(20, 15))
plt.bar(x_axis, y_axis, align="center")
plt.xticks(tick_locations, x_axis, rotation="vertical")
plt.title("Star Wars Starship Sizes")
plt.xlabel("Starships by Name")
plt.ylabel("Starship Length (meters)")
#plt.tight_layout()
plt.show()

# %%
# separate ships into Death Star vs Everything else
deathstar_df = length_starship_df[0:1]
other_starships_df = length_starship_df[1 : 34]

deathstar_df
# Out:
#          Name Length (meters)
# 0  Death Star          120000

# %%
#Find the sum of the lengths of ships in each category and save the figures
deathstar_size = deathstar_df["Length (meters)"].sum()
other_starships_size = other_starships_df["Length (meters)"].sum()

print(f'Death Star Size: {deathstar_size} meters')
print(f'All Other Ship Sizes: {other_starships_size} meters')
# Out:
# Death Star Size: 120000.0 meters
# All Other Ship Sizes: 30286.770000000004 meters

# %%
#Pie Chart for Ship Sizes vs Death Star
labels = ["Death Star Size", "All Other Starships Combined Lengths"]
ship_size_list = [deathstar_size, other_starships_size]
colors = ["red", "skyblue"]
explode = (0.1, 0)
plt.pie(ship_size_list, explode = explode, labels = labels, colors = colors, autopct = "%1.1f%%", shadow = True, startangle = 69)
plt.title("Death Star Size vs All Other Starship Sizes")
plt.savefig("Figures/Pie_Ships_Deathstar_VS.png")
plt.show()
